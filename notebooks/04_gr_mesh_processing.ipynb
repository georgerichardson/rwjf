# %% [markdown]
# MeSH Descriptors
# ================
#
# This notebook contains code to parse and clean the health and medical terms from the NIH Medical Subject Headings. The original files can be found on their FTP site [here](ftp://nlmpubs.nlm.nih.gov/online/mesh/MESH_FILES/xmlmesh/).
#
# There are some existing resources for dealing with MeSH files. These include:
#
# * [Working with MeSH Files in Python](https://code.tutsplus.com/tutorials/working-with-mesh-files-in-python-linking-terms-and-numbers--cms-28587) - a rudimentary approach to parsing the available .bin files.
# * [mesh-tree](https://github.com/scienceai/mesh-tree) - a Java library that parses and provides many useful functions for handling MeSH files.

# %%
import os
import pandas as pd
import numpy as np
import json
import xml.etree.ElementTree as ET
import xmltodict
from datetime import datetime

pd.options.display.max_colwidth = 100
pd.options.display.max_columns = 999

# %%
# %matplotlib inline
#NB I open a standard set of directories

#Paths

#Get the top path
top_path = os.path.dirname(os.getcwd())

#Create the path for external data
ext_data = os.path.join(top_path,'data/external')

#Raw path (for html downloads)

raw_data = os.path.join(top_path,'data/raw')

#And external data
proc_data = os.path.join(top_path,'data/processed')

fig_path = os.path.join(top_path,'reports/figures')

#Get date for saving files
today = datetime.utcnow()

today_str = "_".join([str(x) for x in [today.month, today.day, today.year]])

# %% [markdown]
# ## Approach 1 - xmltodict
#
# This approach uses the very handy `xmltodict` library, which unsurprisingly parses an XML file into a Python dict.

# %%
with open(ext_data + '/desc2018.xml', 'r') as f:
    desc_2018_xml = f.read()

# %%
desc_2018_json = xmltodict.parse(desc_2018_xml)

# %% [markdown]
# This essentially does everything that we need. From here we can create maps between various attributes of the terms, to use for analysis.
#
# As there is no Python API for interfacing with the MeSH services, a useful thing to do might be to create a wrapper class for the MeSH tree. An idea of how this might look and be used is shown here. It would essentially serve as a class to download and parse the latest MeSH files, and to provide convenience functions for creating mappings.

# %%
class MeSHDescriptors():
    def __init__(self, mesh_descriptor_dict=None, file=None, url=None):
        """MeSHDescriptors
        Read, parse or download MeSH descriptor XML files.
        """
        if mesh_descriptor_dict is not None:
            self.descriptors = mesh_descriptor_dict
        elif file is not None:
            self.descriptors = self.read_mesh_xml(file)
        elif url is not None:
            self.descriptors = self.read_remote_xml(file)
    
    def read_mesh_xml(self, file):
        """read_mesh_xml
        Reads and parses from XML file.
        """
        with open(file, 'rb') as f:
            desc_2018_xml = f.read()
        self.descriptors = xmltodict.parse(desc_2018_xml)
    
    def descriptor_ui_2_tree_number(self):
        """descriptor_ui_2_tree_number
        Create a mapping between DescriptorUI and TreeNumber fields.
        """
        mapper = {}
        for d in self.descriptors['DescriptorRecordSet']['DescriptorRecord']:
            k = d['DescriptorUI']
            if k is not None:
                v = d.get('TreeNumberList')
                if v is not None:
                    v = v.get('TreeNumber')
            mapper[k] = v
        return mapper
    
    def to_json(self, file_path=None):
        """to_json
        Serialize the parsed descriptors as a json.
        """
        with open(file_path, 'w') as f:
            json.dump(self.descriptors, f)

# %%
mesh_descriptors = MeSHDescriptors(desc_2018_json)

# %% [markdown]
# As an intial example, we can create a mapping between the _DescriptorUI_ and the _TreeNumber_.

# %%
dui_tree_number_map = mesh_descriptors.descriptor_ui_2_tree_number()

# %%
dui_tree_number_map['D013334']
# Out:
# 'M01.848'

# %% [markdown]
# From here, it is obvious how we might create further mappings that could be useful to make increased use of the full information available fom the descriptors.

# %% [markdown]
# ## 2. An Alternate Route - XML to DataFrame
#
# This was the original approach to parsing the MeSH term XML file. It seems irrelavent now that the `xmltodict` method is in use, however I have left it here for interest.

# %%
# Adapted from 
# http://www.austintaylor.io/lxml/python/pandas/xml/dataframe/2016/07/08/convert-xml-to-pandas-dataframe/
# The original did not account for structures where the last children shared names but not parents as 
# occurs in this dataset. This gives messier names, but all the information.

class XML2DataFrame:

    def __init__(self, xml_data):
#         parser = ET.XMLParser(encoding="utf-8")
#         self.root = ET.fromstring(xml_data, parser=parser)
        self.root = ET.XML(xml_data)

    def parse_root(self, root):
        return [self.parse_element(child, 'Root') for child in iter(root)]

    def parse_element(self, element, parent_name, parsed=None):
        if parsed is None:
            parsed = dict()
        for key in element.keys():
            parsed[parent_name + key] = element.attrib.get(key)
        if element.text:
            h_key = parent_name + element.tag
#             if h_key in parsed:
#                 h_key = h_key + '_1'
            parsed[h_key] = element.text
        for child in list(element):
            self.parse_element(child, element.tag, parsed)
        return parsed

    def process_data(self):
        structure_data = self.parse_root(self.root)
        return pd.DataFrame(structure_data)

# %%
desc_2018_df.head()
# Out:
#   AllowableQualifierAbbreviation AllowableQualifierQualifierReferredTo  \
# 0                             TO                               \n
# 1                             TO                               \n
# 2                             ES                               \n
# 3                            NaN                                   NaN
# 4                             VI                               \n
#
#   AllowableQualifiersListAllowableQualifier  \
# 0                                    \n
# 1                                    \n
# 2                                    \n
# 3                                       NaN
# 4                                    \n
#
#                                                                                       ConceptCASN1Name  \
# 0  4-Benzoxazolecarboxylic acid, 5-(methylamino)-2-((3,9,11-trimethyl-8-(1-methyl-2-oxo-2-(1H-pyrro...
# 1                        Phosphorothioic acid, O,O'-(thiodi-4,1-phenylene) O,O,O',O'-tetramethyl ester
# 2                                                                                                  NaN
# 3                                                                                                  NaN
# 4                                                                                                  NaN
#
#   ConceptConceptName ConceptConceptRelationList ConceptConceptUI  \
# 0            \n                         \n              M0353609
# 1            \n                         \n              M0352200
# 2            \n                             NaN         M0000003
# 3            \n                         \n              M0511063
# 4            \n                             NaN         M0000005
#
#   ConceptListConcept ConceptListPreferredConceptYN  ConceptNameString  \
# 0             \n                                 N            A-23187
# 1             \n                                 N              Difos
# 2             \n                                 Y          Abattoirs
# 3             \n                                 N  Acronyms as Topic
# 4             \n                                 Y            Abdomen
#
#   ConceptRegistryNumber ConceptRelatedRegistryNumberList  \
# 0                     0                          \n
# 1                     0                          \n
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
#
#   ConceptRelationConcept1UI ConceptRelationConcept2UI  \
# 0                  M0000001                  M0353609
# 1                  M0000002                  M0352200
# 2                       NaN                       NaN
# 3                  M0000004                  M0511063
# 4                       NaN                       NaN
#
#   ConceptRelationListConceptRelation ConceptRelationListRelationName  \
# 0                            \n                                  NRW
# 1                            \n                                  NRW
# 2                                NaN                             NaN
# 3                            \n                                  NRW
# 4                                NaN                             NaN
#
#                                                                                       ConceptScopeNote  \
# 0  An ionophorous, polyether antibiotic from Streptomyces chartreusensis. It binds and transports C...
# 1                                                            An organothiophosphate insecticide.\n
# 2                                   Places where animals are slaughtered and dressed for market.\n
# 3                      Works about shortened forms of written words or phrases used for brevity.\n
# 4                          That portion of the body that lies between the THORAX and the PELVIS.\n
#
#   ConceptTermList DateCreatedDay DateCreatedMonth DateCreatedYear  \
# 0         \n                  08               03            1990
# 1         \n                  07               10            1986
# 2         \n                  29               03            1974
# 3         \n                  29               06            2007
# 4         \n                  01               01            1999
#
#   DateEstablishedDay DateEstablishedMonth DateEstablishedYear DateRevisedDay  \
# 0                 01                   01                1984             27
# 1                 01                   01                1991             08
# 2                 01                   01                1966             08
# 3                 01                   01                1960             30
# 4                 01                   01                1966             09
#
#   DateRevisedMonth DateRevisedYear    DescriptorNameString  \
# 0               05            2016      Calcium Ionophores
# 1               07            2013            Insecticides
# 2               06            2016               Abattoirs
# 3               06            2017  Abbreviations as Topic
# 4               08            2016      Abdominal Injuries
#
#   DescriptorRecordAllowableQualifiersList  \
# 0                                   \n
# 1                                   \n
# 2                                   \n
# 3                                     NaN
# 4                                   \n
#
#                                                                             DescriptorRecordAnnotation  \
# 0                                                                                                  NaN
# 1  for use to kill or control insects, use no qualifiers on the insecticide or the insect; appropri...
# 2                                                                                                  NaN
# 3                            includes acronyms; do not confuse with Publication Type ABBREVIATIONS\n
# 4  GEN: prefer specifics; abdom muscles = ABDOMINAL MUSCLES but RECTUS ABDOMINIS is available; abdo...
#
#   DescriptorRecordConceptList DescriptorRecordConsiderAlso  \
# 0                       \n                             NaN
# 1                       \n                             NaN
# 2                       \n                             NaN
# 3                       \n                             NaN
# 4                       \n                             NaN
#
#   DescriptorRecordDateCreated DescriptorRecordDateEstablished  \
# 0                       \n                              \n
# 1                       \n                              \n
# 2                       \n                              \n
# 3                       \n                              \n
# 4                       \n                              \n
#
#   DescriptorRecordDateRevised DescriptorRecordDescriptorName  \
# 0                       \n                             \n
# 1                       \n                             \n
# 2                       \n                             \n
# 3                       \n                             \n
# 4                       \n                             \n
#
#   DescriptorRecordDescriptorUI DescriptorRecordEntryCombinationList  \
# 0                      D000001                                  NaN
# 1                      D000002                                  NaN
# 2                      D000003                                  NaN
# 3                      D000004                                  NaN
# 4                      D000005                                \n
#
#                                                        DescriptorRecordHistoryNote  \
# 0                  91(75); was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
# 1  96; was ABATE 1972-95 (see under INSECTICIDES, ORGANOTHIOPHOSPHATE 1972-90)\n
# 2                                                                              NaN
# 3                                                                   2008(1963)\n
# 4                                                                              NaN
#
#   DescriptorRecordNLMClassificationNumber  \
# 0                                     NaN
# 1                                     NaN
# 2                                  WA 707
# 3                                     NaN
# 4                                     NaN
#
#                      DescriptorRecordOnlineNote  \
# 0  use CALCIMYCIN to search A 23187 1975-90\n
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   DescriptorRecordPharmacologicalActionList  \
# 0                                   \n
# 1                                   \n
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   DescriptorRecordPreviousIndexingList  \
# 0                                \n
# 1                                \n
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                                     DescriptorRecordPublicMeSHNote  \
# 0                      91; was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
# 1  96; was ABATE 1972-95 (see under INSECTICIDES, ORGANOTHIOPHOSPHATE 1972-90)\n
# 2                                                                              NaN
# 3                                            2008; see ABBREVIATIONS 1963-2007\n
# 4                                                                              NaN
#
#   DescriptorRecordSeeRelatedList DescriptorRecordTreeNumberList  \
# 0                            NaN                          \n
# 1                            NaN                          \n
# 2                            NaN                          \n
# 3                            NaN                          \n
# 4                            NaN                          \n
#
#   DescriptorReferredToDescriptorName DescriptorReferredToDescriptorUI  \
# 0                        \n                                   D061207
# 1                        \n                                   D007306
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                          \n                                 D000007
#
#   ECINDescriptorReferredTo ECINQualifierReferredTo ECOUTDescriptorReferredTo  \
# 0                      NaN                     NaN                       NaN
# 1                      NaN                     NaN                       NaN
# 2                      NaN                     NaN                       NaN
# 3                      NaN                     NaN                       NaN
# 4                 \n                      \n                        \n
#
#   ECOUTQualifierReferredTo EntryCombinationECIN EntryCombinationECOUT  \
# 0                      NaN                  NaN                   NaN
# 1                      NaN                  NaN                   NaN
# 2                      NaN                  NaN                   NaN
# 3                      NaN                  NaN                   NaN
# 4                      NaN              \n                    \n
#
#   EntryCombinationListEntryCombination  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                               \n
#
#   PharmacologicalActionDescriptorReferredTo  \
# 0                                 \n
# 1                                 \n
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   PharmacologicalActionListPharmacologicalAction  \
# 0                                       \n
# 1                                       \n
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   PreviousIndexingListPreviousIndexing QualifierNameString  \
# 0         Carboxylic Acids (1973-1974)            toxicity
# 1             Insecticides (1966-1971)            toxicity
# 2                                  NaN              ethics
# 3                                  NaN                 NaN
# 4                                  NaN            injuries
#
#   QualifierReferredToQualifierName QualifierReferredToQualifierUI  \
# 0                         \n                              Q000633
# 1                         \n                              Q000633
# 2                         \n                              Q000941
# 3                              NaN                            NaN
# 4                        \n                               Q000293
#
#   RelatedRegistryNumberListRelatedRegistryNumber RootDescriptorClass  \
# 0                        52665-69-7 (Calcimycin)                   1
# 1                            3383-96-8 (Temefos)                   1
# 2                                            NaN                   1
# 3                                            NaN                   1
# 4                                            NaN                   1
#
#   RootDescriptorRecord SeeRelatedDescriptorDescriptorReferredTo  \
# 0                 \n                                        NaN
# 1                 \n                                        NaN
# 2                 \n                                        NaN
# 3                 \n                                        NaN
# 4                 \n                                        NaN
#
#   SeeRelatedListSeeRelatedDescriptor TermDateCreated TermEntryVersion  \
# 0                                NaN       \n                     NaN
# 1                                NaN       \n                     NaN
# 2                                NaN       \n                     NaN
# 3                                NaN       \n                     NaN
# 4                                NaN       \n                     NaN
#
#   TermListConceptPreferredTermYN TermListIsPermutedTermYN TermListLexicalTag  \
# 0                              N                        Y                NON
# 1                              Y                        N                TRD
# 2                              N                        Y                NON
# 3                              Y                        N                NON
# 4                              N                        Y                NON
#
#   TermListRecordPreferredTermYN TermListTerm TermSortVersion  \
# 0                             N     \n                   NaN
# 1                             N     \n                   NaN
# 2                             N     \n                   NaN
# 3                             N     \n                   NaN
# 4                             N     \n                   NaN
#
#            TermString TermTermUI TermThesaurusIDlist  \
# 0  A23187, Antibiotic    T000003           \n
# 1               Difos    T000006           \n
# 2      Slaughterhouse    T000010           \n
# 3   Acronyms as Topic    T701041           \n
# 4            Abdomens    T000012           \n
#
#   ThesaurusIDlistThesaurusID TreeNumberListTreeNumber
# 0                 NLM (1991)      D03.633.100.221.173
# 1                 UNK (19XX)      D02.886.300.692.800
# 2                 UNK (19XX)              J03.540.020
# 3                 NLM (2008)  L01.559.598.400.556.131
# 4                 NLM (1966)              A01.923.047

# %%
desc_2018_df.columns
# Out:
# Index(['AllowableQualifierAbbreviation',
#        'AllowableQualifierQualifierReferredTo',
#        'AllowableQualifiersListAllowableQualifier', 'ConceptCASN1Name',
#        'ConceptConceptName', 'ConceptConceptRelationList', 'ConceptConceptUI',
#        'ConceptListConcept', 'ConceptListPreferredConceptYN',
#        'ConceptNameString', 'ConceptRegistryNumber',
#        'ConceptRelatedRegistryNumberList', 'ConceptRelationConcept1UI',
#        'ConceptRelationConcept2UI', 'ConceptRelationListConceptRelation',
#        'ConceptRelationListRelationName', 'ConceptScopeNote',
#        'ConceptTermList', 'DateCreatedDay', 'DateCreatedMonth',
#        'DateCreatedYear', 'DateEstablishedDay', 'DateEstablishedMonth',
#        'DateEstablishedYear', 'DateRevisedDay', 'DateRevisedMonth',
#        'DateRevisedYear', 'DescriptorNameString',
#        'DescriptorRecordAllowableQualifiersList', 'DescriptorRecordAnnotation',
#        'DescriptorRecordConceptList', 'DescriptorRecordConsiderAlso',
#        'DescriptorRecordDateCreated', 'DescriptorRecordDateEstablished',
#        'DescriptorRecordDateRevised', 'DescriptorRecordDescriptorName',
#        'DescriptorRecordDescriptorUI', 'DescriptorRecordEntryCombinationList',
#        'DescriptorRecordHistoryNote',
#        'DescriptorRecordNLMClassificationNumber', 'DescriptorRecordOnlineNote',
#        'DescriptorRecordPharmacologicalActionList',
#        'DescriptorRecordPreviousIndexingList',
#        'DescriptorRecordPublicMeSHNote', 'DescriptorRecordSeeRelatedList',
#        'DescriptorRecordTreeNumberList', 'DescriptorReferredToDescriptorName',
#        'DescriptorReferredToDescriptorUI', 'ECINDescriptorReferredTo',
#        'ECINQualifierReferredTo', 'ECOUTDescriptorReferredTo',
#        'ECOUTQualifierReferredTo', 'EntryCombinationECIN',
#        'EntryCombinationECOUT', 'EntryCombinationListEntryCombination',
#        'PharmacologicalActionDescriptorReferredTo',
#        'PharmacologicalActionListPharmacologicalAction',
#        'PreviousIndexingListPreviousIndexing', 'QualifierNameString',
#        'QualifierReferredToQualifierName', 'QualifierReferredToQualifierUI',
#        'RelatedRegistryNumberListRelatedRegistryNumber', 'RootDescriptorClass',
#        'RootDescriptorRecord', 'SeeRelatedDescriptorDescriptorReferredTo',
#        'SeeRelatedListSeeRelatedDescriptor', 'TermDateCreated',
#        'TermEntryVersion', 'TermListConceptPreferredTermYN',
#        'TermListIsPermutedTermYN', 'TermListLexicalTag',
#        'TermListRecordPreferredTermYN', 'TermListTerm', 'TermSortVersion',
#        'TermString', 'TermTermUI', 'TermThesaurusIDlist',
#        'ThesaurusIDlistThesaurusID', 'TreeNumberListTreeNumber'],
#       dtype='object')

# %%
desc_2018_df.head(1)
# Out:
#   AllowableQualifierAbbreviation AllowableQualifierQualifierReferredTo  \
# 0                             TO                               \n
#
#   AllowableQualifiersListAllowableQualifier  \
# 0                                    \n
#
#                                                                                       ConceptCASN1Name  \
# 0  4-Benzoxazolecarboxylic acid, 5-(methylamino)-2-((3,9,11-trimethyl-8-(1-methyl-2-oxo-2-(1H-pyrro...
#
#   ConceptConceptName ConceptConceptRelationList ConceptConceptUI  \
# 0            \n                         \n              M0353609
#
#   ConceptListConcept ConceptListPreferredConceptYN ConceptNameString  \
# 0             \n                                 N           A-23187
#
#   ConceptRegistryNumber ConceptRelatedRegistryNumberList  \
# 0                     0                          \n
#
#   ConceptRelationConcept1UI ConceptRelationConcept2UI  \
# 0                  M0000001                  M0353609
#
#   ConceptRelationListConceptRelation ConceptRelationListRelationName  \
# 0                            \n                                  NRW
#
#                                                                                       ConceptScopeNote  \
# 0  An ionophorous, polyether antibiotic from Streptomyces chartreusensis. It binds and transports C...
#
#   ConceptTermList DateCreatedDay DateCreatedMonth DateCreatedYear  \
# 0         \n                  08               03            1990
#
#   DateEstablishedDay DateEstablishedMonth DateEstablishedYear DateRevisedDay  \
# 0                 01                   01                1984             27
#
#   DateRevisedMonth DateRevisedYear DescriptorNameString  \
# 0               05            2016   Calcium Ionophores
#
#   DescriptorRecordAllowableQualifiersList DescriptorRecordAnnotation  \
# 0                                   \n                           NaN
#
#   DescriptorRecordConceptList DescriptorRecordConsiderAlso  \
# 0                       \n                             NaN
#
#   DescriptorRecordDateCreated DescriptorRecordDateEstablished  \
# 0                       \n                              \n
#
#   DescriptorRecordDateRevised DescriptorRecordDescriptorName  \
# 0                       \n                             \n
#
#   DescriptorRecordDescriptorUI DescriptorRecordEntryCombinationList  \
# 0                      D000001                                  NaN
#
#                                        DescriptorRecordHistoryNote  \
# 0  91(75); was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
#
#   DescriptorRecordNLMClassificationNumber  \
# 0                                     NaN
#
#                      DescriptorRecordOnlineNote  \
# 0  use CALCIMYCIN to search A 23187 1975-90\n
#
#   DescriptorRecordPharmacologicalActionList  \
# 0                                   \n
#
#   DescriptorRecordPreviousIndexingList  \
# 0                                \n
#
#                                 DescriptorRecordPublicMeSHNote  \
# 0  91; was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
#
#   DescriptorRecordSeeRelatedList DescriptorRecordTreeNumberList  \
# 0                            NaN                          \n
#
#   DescriptorReferredToDescriptorName DescriptorReferredToDescriptorUI  \
# 0                        \n                                   D061207
#
#   ECINDescriptorReferredTo ECINQualifierReferredTo ECOUTDescriptorReferredTo  \
# 0                      NaN                     NaN                       NaN
#
#   ECOUTQualifierReferredTo EntryCombinationECIN EntryCombinationECOUT  \
# 0                      NaN                  NaN                   NaN
#
#   EntryCombinationListEntryCombination  \
# 0                                  NaN
#
#   PharmacologicalActionDescriptorReferredTo  \
# 0                                 \n
#
#   PharmacologicalActionListPharmacologicalAction  \
# 0                                       \n
#
#   PreviousIndexingListPreviousIndexing QualifierNameString  \
# 0         Carboxylic Acids (1973-1974)            toxicity
#
#   QualifierReferredToQualifierName QualifierReferredToQualifierUI  \
# 0                         \n                              Q000633
#
#   RelatedRegistryNumberListRelatedRegistryNumber RootDescriptorClass  \
# 0                        52665-69-7 (Calcimycin)                   1
#
#   RootDescriptorRecord SeeRelatedDescriptorDescriptorReferredTo  \
# 0                 \n                                        NaN
#
#   SeeRelatedListSeeRelatedDescriptor TermDateCreated TermEntryVersion  \
# 0                                NaN       \n                     NaN
#
#   TermListConceptPreferredTermYN TermListIsPermutedTermYN TermListLexicalTag  \
# 0                              N                        Y                NON
#
#   TermListRecordPreferredTermYN TermListTerm TermSortVersion  \
# 0                             N     \n                   NaN
#
#            TermString TermTermUI TermThesaurusIDlist  \
# 0  A23187, Antibiotic    T000003           \n
#
#   ThesaurusIDlistThesaurusID TreeNumberListTreeNumber
# 0                 NLM (1991)      D03.633.100.221.173

# %%
desc_2018_df.drop([
       'AllowableQualifierQualifierReferredTo',
       'AllowableQualifiersListAllowableQualifier',
       'ConceptConceptName', 'ConceptConceptRelationList',
       'ConceptListConcept',
       'ConceptRelatedRegistryNumberList', 'ConceptRelationListConceptRelation',
       'DescriptorRecordAllowableQualifiersList',
       'DescriptorRecordConceptList', 
       'DescriptorRecordDateCreated', 'DescriptorRecordDateEstablished',
       'DescriptorRecordDateRevised', 'DescriptorRecordDescriptorName',
       'DescriptorRecordPharmacologicalActionList',
       'DescriptorRecordPreviousIndexingList',
       'DescriptorRecordTreeNumberList', 'DescriptorReferredToDescriptorName',
       'PharmacologicalActionDescriptorReferredTo',
       'PharmacologicalActionListPharmacologicalAction',
       'QualifierReferredToQualifierName',
       'RootDescriptorRecord',
       'TermDateCreated',
       'TermListTerm',
       'TermThesaurusIDlist','ECINDescriptorReferredTo',
       'ECINQualifierReferredTo',
       'ECOUTDescriptorReferredTo',
       'ECOUTQualifierReferredTo',
       'EntryCombinationECIN',
       'EntryCombinationECOUT'],
        axis=1, inplace=True)

# %%
desc_2018_df.head(1)
# Out:
#   AllowableQualifierAbbreviation  \
# 0                             TO
#
#                                                                                       ConceptCASN1Name  \
# 0  4-Benzoxazolecarboxylic acid, 5-(methylamino)-2-((3,9,11-trimethyl-8-(1-methyl-2-oxo-2-(1H-pyrro...
#
#   ConceptConceptUI ConceptListPreferredConceptYN ConceptNameString  \
# 0         M0353609                             N           A-23187
#
#   ConceptRegistryNumber ConceptRelationConcept1UI ConceptRelationConcept2UI  \
# 0                     0                  M0000001                  M0353609
#
#   ConceptRelationListRelationName  \
# 0                             NRW
#
#                                                                                       ConceptScopeNote  \
# 0  An ionophorous, polyether antibiotic from Streptomyces chartreusensis. It binds and transports C...
#
#   ConceptTermList DateCreatedDay DateCreatedMonth DateCreatedYear  \
# 0         \n                  08               03            1990
#
#   DateEstablishedDay DateEstablishedMonth DateEstablishedYear DateRevisedDay  \
# 0                 01                   01                1984             27
#
#   DateRevisedMonth DateRevisedYear DescriptorNameString  \
# 0               05            2016   Calcium Ionophores
#
#   DescriptorRecordAnnotation DescriptorRecordConsiderAlso  \
# 0                        NaN                          NaN
#
#   DescriptorRecordDescriptorUI DescriptorRecordEntryCombinationList  \
# 0                      D000001                                  NaN
#
#                                        DescriptorRecordHistoryNote  \
# 0  91(75); was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
#
#   DescriptorRecordNLMClassificationNumber  \
# 0                                     NaN
#
#                      DescriptorRecordOnlineNote  \
# 0  use CALCIMYCIN to search A 23187 1975-90\n
#
#                                 DescriptorRecordPublicMeSHNote  \
# 0  91; was A 23187 1975-90 (see under ANTIBIOTICS 1975-83)\n
#
#   DescriptorRecordSeeRelatedList DescriptorReferredToDescriptorUI  \
# 0                            NaN                          D061207
#
#   EntryCombinationListEntryCombination PreviousIndexingListPreviousIndexing  \
# 0                                  NaN         Carboxylic Acids (1973-1974)
#
#   QualifierNameString QualifierReferredToQualifierUI  \
# 0            toxicity                        Q000633
#
#   RelatedRegistryNumberListRelatedRegistryNumber RootDescriptorClass  \
# 0                        52665-69-7 (Calcimycin)                   1
#
#   SeeRelatedDescriptorDescriptorReferredTo SeeRelatedListSeeRelatedDescriptor  \
# 0                                      NaN                                NaN
#
#   TermEntryVersion TermListConceptPreferredTermYN TermListIsPermutedTermYN  \
# 0              NaN                              N                        Y
#
#   TermListLexicalTag TermListRecordPreferredTermYN TermSortVersion  \
# 0                NON                             N             NaN
#
#            TermString TermTermUI ThesaurusIDlistThesaurusID  \
# 0  A23187, Antibiotic    T000003                 NLM (1991)
#
#   TreeNumberListTreeNumber
# 0      D03.633.100.221.173

# %%
desc_2018_df.rename(columns={'AllowableQualifierAbbreviation': 'QualifierAbbreviation',
                            'ConceptConceptUI': 'ConceptUI',
                            'ConceptListPreferredConceptYN': 'PreferredConceptYN',
                            'ConceptRelationConcept1UI': 'Concept1UI',
                            'ConceptRelationConcept1UI': 'Concept2UI',
                            'ConceptRelationListRelationName' : 'ConceptRelationName',
                            'PreviousIndexingListPreviousIndexing': 'PreviousIndexing',
                            'EntryCombinationListEntryCombination': 'EntryCombination',
                            'RelatedRegistryNumberListRelatedRegistryNumber': 'RelatedRegistryNumber',
                            'SeeRelatedDescriptorDescriptorReferredTo': 'DescriptorReferredTo',
                            'SeeRelatedListSeeRelatedDescriptor': 'SeeRelatedDescriptor',
                            'TermListConceptPreferredTermYN': 'PreferredTermYN',
                            'TermListIsPermutedTermYN': 'IsPermutedTermYN',
                            'ThesaurusIDlistThesaurusID': 'ThesaurusID',
                            'TreeNumberListTreeNumber': 'TreeNumber'}, inplace=True)

# %%
# desc_2018_df['TreeNumber'][pd.isnull(desc_2018_df['TreeNumber'])] = ['U01', 'U02']
desc_2018_df = desc_2018_df[~pd.isnull(desc_2018_df['TreeNumber'])]

# %% [markdown]
# MeSH codes resemble the format "A01.343.124.243" with up to 12 levels, and where the first letter denotes the coarsest category. We want to know the position in the hierarchy for each word, so we count the number of splits in the code for each term.

# %%
code_splits = []

for c in desc_2018_df['TreeNumber'].str.split('.'):
    code_splits.append(c)

# %%
# mesh_tree_codes = ['.'.join(c) for c in code_splits]
code_lengths = [len(c) for c in code_splits]
max_code_length = max(code_lengths)
# desc_2018_df['MeshTreeCode'] = mesh_tree_codes

# %%
print(max_code_length)
# Out:
# 13

# %%
# reset

# for c in desc_2018_df.columns:
#     if 'tree' in c:
#         desc_2018_df.drop(c, axis=1, inplace=True)

# %%
desc_2018_df['tree_number_0'] = [c[0][0] for c in code_splits]

# %%
code_splits[200]
# Out:
# ['D12', '776', '664', '962', '813', '500', '875']

# %% [markdown]
# Let's add columns for each code order, so we can group terms together under common codes later.

# %%
for i in range(1, max_code_length):
    tree_lvl_codes = []
    for c in code_splits:
        if len(c) >= i:
            tree_lvl_codes.append('.'.join(c[:i]))
        else:
            tree_lvl_codes.append(np.nan)
    desc_2018_df['tree_number_{}'.format(i)] = tree_lvl_codes

# %% [markdown]
# We want to map the codes to actual terms, so starting with the 0th level, we map terms obtained manually from the MeSH website.

# %%
# from https://meshb.nlm.nih.gov/treeView
tree_0_map = {
    'A': 'anatomy',
    'B': 'organisms',
    'C': 'diseases',
    'D': 'chemicals and drugs',
    'E': 'analytical, diagnostic, and therapeutic techniques, and equipment',
    'F': 'psychiatry and psychology',
    'G': 'phenomena and processes',
    'H': 'disciplines and occupations',
    'I': 'anthropology, education, sociology, and social phenomena',
    'J': 'technology, industry, and agriculture',
    'K': 'humanities',
    'L': 'information science',
    'M': 'named groups',
    'N': 'health care',
    'V': 'publication characteristics',
    'Z': 'geographicals'
}

# %%
desc_2018_df['tree_string_0'] = desc_2018_df['tree_number_0'].map(tree_0_map)

# %% [markdown]
# Some of the original strings are reversed using commas. To help matching in the documents we should put them in correct order.

# %%
# desc_2018_df.to_csv(proc_data + '/mesh_codes_cleaned_{}.csv'.format(today_str), index=False)
desc_2018_df = pd.read_csv(proc_data + '/mesh_codes_cleaned_{}.csv'.format('5_3_2018')).drop('Unnamed: 0', axis=1)
# Out:
# /Users/grichardson/miniconda3/envs/rwjf/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (23,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def process_string(string):
    string = string.split(', ')
    string = ' '.join(string[::-1])
    return string.lower()

# %%
for c in desc_2018_df.columns:
    if 'String' in c:
        print(c)
# Out:
# ConceptNameString
# DescriptorNameString
# QualifierNameString
# TermString

# %%
desc_2018_df['ConceptNameString'][:10]
# Out:
# 0                  A-23187
# 1                    Difos
# 2                Abattoirs
# 3        Acronyms as Topic
# 4                  Abdomen
# 5           Abdomen, Acute
# 6       Abdominal Injuries
# 7      Abdominal Neoplasms
# 8    Transversus Abdominis
# 9           Abducens Nerve
# Name: ConceptNameString, dtype: object

# %%
desc_2018_df['DescriptorNameString'][:10]
# Out:
# 0        Calcium Ionophores
# 1              Insecticides
# 2                 Abattoirs
# 3    Abbreviations as Topic
# 4        Abdominal Injuries
# 5            Abdomen, Acute
# 6        Abdominal Injuries
# 7       Abdominal Neoplasms
# 8            Abdominal Wall
# 9          Abducens Nucleus
# Name: DescriptorNameString, dtype: object

# %%
desc_2018_df['QualifierNameString'][:10]
# Out:
# 0          toxicity
# 1          toxicity
# 2            ethics
# 3               NaN
# 4          injuries
# 5           nursing
# 6         pathology
# 7    ultrastructure
# 8    ultrastructure
# 9          injuries
# Name: QualifierNameString, dtype: object

# %%
desc_2018_df['TermString'][:10]
# Out:
# 0       A23187, Antibiotic
# 1                    Difos
# 2           Slaughterhouse
# 3        Acronyms as Topic
# 4                 Abdomens
# 5           Acute Abdomens
# 6        Injury, Abdominal
# 7     Neoplasms, Abdominal
# 8    Transverse Abdominals
# 9       Nerve VIs, Cranial
# Name: TermString, dtype: object

# %%
desc_2018_df['ConceptStringProcessed'] = desc_2018_df['ConceptNameString'].apply(lambda x: process_string(x))
desc_2018_df['DescriptorStringProcessed'] = desc_2018_df['DescriptorNameString'].apply(lambda x: process_string(x))
# desc_2018_df['QualifierStringProcessed'] = desc_2018_df['QualifierNameString'].apply(lambda x: process_string(x))
desc_2018_df['TermStringProcessed'] = desc_2018_df['TermString'].apply(lambda x: process_string(x))

# %% [markdown]
# For each level, take the tree codes and the processed strings, but only for the ones where the next level up is NaN. This means that only ones which finish at this level of the tree are taken. Set the index of the dataframe to the tree codes and convert to a dict that maps codes to strings. Map that dict on to the codes for the next level up.

# %%
def expand_string_tree(df, string_column, max_code_length=13):
    for i in range(1, max_code_length - 1):
        tree_name_map = desc_2018_df[['TreeNumber', string_column]][pd.isnull(desc_2018_df['tree_number_{}'.format(i + 1)])].set_index('TreeNumber').to_dict()
        tree_name_map = tree_name_map[string_column]
        tree_name_map.pop(np.nan, None)
        desc_2018_df['tree_{}_{}'.format(string_column, i)] = desc_2018_df['tree_number_{}'.format(i)].map(tree_name_map, na_action='ignore')
    desc_2018_df['tree_{}_{}'.format(string_column, max_code_length - 1)] = np.nan
    return df

# %%
for c in ['ConceptStringProcessed', 'DescriptorStringProcessed', 'TermStringProcessed']:
    desc_2018_df = expand_string_tree(desc_2018_df, c)

# %%
# desc_2018_df.to_csv(proc_data + '/mesh_codes_cleaned_{}.csv'.format(today_str), index=False)

# %% [markdown]
# After this there are some broken codes, due to duplicate entries in the tree, but these are relatively few in number.

# %%
desc_2018_df['tree_order'] = code_lengths

# %% [markdown]
# Finally export as a json.

# %%
reoriented = desc_2018_df.set_index('DescriptorRecordDescriptorUI')

# %%
concept_string_dict = reoriented.to_dict(orient='index')

# %%
reoriented.to_json(proc_data + '/mesh_codes_processed_DUI_{}.json'.format(today_str), orient='index')

# %% [markdown]
# Need to do a second iteration of this where the tree is not built on one of the terms, but rather the tree numbers.
#
# Possible structure that we might want to obtain later:
#
# ```
# {'A': {'level': 0,
#        'term': 'humans',
#        'children': {'A01': {...
#                            }
#                     ...
#                    }
#        ...
#       }
#  ...
# }
#
# ```

# %%
reoriented = desc_2018_df.set_index('TreeNumber')

# %%
concept_string_dict = reoriented.to_dict(orient='index')

# %%
reoriented.to_json(proc_data + '/mesh_codes_processed_tree_number_{}.json'.format(today_str), orient='index')

# %%
desc_2018_df = pd.read_json('../data/processed/mesh_codes_processed_5_4_2018.json')

# %%
desc_2018_df.set_index('TreeNumber').to_json('../data/processed/mesh_codes_processed_5_8_2018.json', orient='index')

# %%
desc_2018_df_2[desc_2018_df_2['ConceptNameString'].str.contains('Volition')]
# Out:
#          Concept2UI ConceptCASN1Name ConceptNameString ConceptRegistryNumber  \
# volition       None             None          Volition                  None
#
#          ConceptRelationConcept2UI ConceptRelationName  \
# volition                      None                None
#
#                                                ConceptScopeNote  \
# volition  Voluntary activity without external compulsion.\n
#
#          ConceptTermList ConceptUI DateCreatedDay DateCreatedMonth  \
# volition         \n       M0022838             30               03
#
#          DateCreatedYear DateEstablishedDay DateEstablishedMonth  \
# volition            1974                 01                   01
#
#          DateEstablishedYear DateRevisedDay DateRevisedMonth DateRevisedYear  \
# volition                1966             23               05            1995
#
#          DescriptorNameString DescriptorRecordAnnotation  \
# volition             Volition                       None
#
#          DescriptorRecordConsiderAlso DescriptorRecordDescriptorUI  \
# volition                         None                      D014836
#
#          DescriptorRecordEntryCombinationList DescriptorRecordHistoryNote  \
# volition                                 None                        None
#
#          DescriptorRecordNLMClassificationNumber DescriptorRecordOnlineNote  \
# volition                                    None                       None
#
#          DescriptorRecordPublicMeSHNote DescriptorRecordSeeRelatedList  \
# volition                           None                           None
#
#          DescriptorReferredTo DescriptorReferredToDescriptorUI  \
# volition                 None                             None
#
#          DescriptorStringProcessed EntryCombination IsPermutedTermYN  \
# volition                  volition             None                N
#
#          PreferredConceptYN PreferredTermYN PreviousIndexing  \
# volition                  Y               N             None
#
#          QualifierAbbreviation QualifierNameString  \
# volition                    ES              ethics
#
#          QualifierReferredToQualifierUI RelatedRegistryNumber  \
# volition                        Q000941                  None
#
#          RootDescriptorClass SeeRelatedDescriptor TermEntryVersion  \
# volition                   1                 None             None
#
#          TermListLexicalTag TermListRecordPreferredTermYN TermSortVersion  \
# volition                NON                             N            None
#
#          TermString TermStringProcessed TermTermUI ThesaurusID   TreeNumber  \
# volition       Will                will    T043363  UNK (19XX)  F02.463.902
#
#          tree_ConceptStringProcessed_1 tree_ConceptStringProcessed_10  \
# volition         psychologic processes                           None
#
#          tree_ConceptStringProcessed_11 tree_ConceptStringProcessed_12  \
# volition                           None                           None
#
#          tree_ConceptStringProcessed_2 tree_ConceptStringProcessed_3  \
# volition              mental processes                      volition
#
#          tree_ConceptStringProcessed_4 tree_ConceptStringProcessed_5  \
# volition                          None                          None
#
#          tree_ConceptStringProcessed_6 tree_ConceptStringProcessed_7  \
# volition                          None                          None
#
#          tree_ConceptStringProcessed_8 tree_ConceptStringProcessed_9  \
# volition                          None                          None
#
#          tree_DescriptorStringProcessed_1 tree_DescriptorStringProcessed_10  \
# volition          psychological phenomena                              None
#
#          tree_DescriptorStringProcessed_11 tree_DescriptorStringProcessed_12  \
# volition                              None                              None
#
#          tree_DescriptorStringProcessed_2 tree_DescriptorStringProcessed_3  \
# volition                 mental processes                         volition
#
#          tree_DescriptorStringProcessed_4 tree_DescriptorStringProcessed_5  \
# volition                             None                             None
#
#          tree_DescriptorStringProcessed_6 tree_DescriptorStringProcessed_7  \
# volition                             None                             None
#
#          tree_DescriptorStringProcessed_8 tree_DescriptorStringProcessed_9  \
# volition                             None                             None
#
#          tree_TermStringProcessed_1 tree_TermStringProcessed_10  \
# volition     psychological processe                        None
#
#          tree_TermStringProcessed_11 tree_TermStringProcessed_12  \
# volition                        None                        None
#
#             tree_TermStringProcessed_2 tree_TermStringProcessed_3  \
# volition  human information processing                       will
#
#          tree_TermStringProcessed_4 tree_TermStringProcessed_5  \
# volition                       None                       None
#
#          tree_TermStringProcessed_6 tree_TermStringProcessed_7  \
# volition                       None                       None
#
#          tree_TermStringProcessed_8 tree_TermStringProcessed_9 tree_number_0  \
# volition                       None                       None             F
#
#          tree_number_1 tree_number_10 tree_number_11 tree_number_12  \
# volition           F02           None           None           None
#
#          tree_number_2 tree_number_3 tree_number_4 tree_number_5  \
# volition       F02.463   F02.463.902          None          None
#
#          tree_number_6 tree_number_7 tree_number_8 tree_number_9 tree_order  \
# volition          None          None          None          None          3
#
#                       tree_string_0
# volition  psychiatry and psychology

# %%
df = pd.read_json('../data/processed/mesh_codes_processed_5_4_2018.json', orient='index')

# %%
df = df.reset_index()

# %%
df.rename(columns={'index': 'DescriptorRecordDescriptorUI'}, inplace=True)

# %%
df.columns
# Out:
# Index(['DescriptorRecordDescriptorUI', 'Concept2UI', 'ConceptCASN1Name',
#        'ConceptNameString', 'ConceptRegistryNumber',
#        'ConceptRelationConcept2UI', 'ConceptRelationName', 'ConceptScopeNote',
#        'ConceptTermList', 'ConceptUI',
#        ...
#        'tree_number_2', 'tree_number_3', 'tree_number_4', 'tree_number_5',
#        'tree_number_6', 'tree_number_7', 'tree_number_8', 'tree_number_9',
#        'tree_order', 'tree_string_0'],
#       dtype='object', length=103)

# %%
df.head()
# Out:
#                                                Concept2UI  \
# (+)-isomer bay-k-8644                            M0002232
# (+)-isomer methoxyhydroxyphenylglycol            M0013606
# (+)-isomer oxyphenonium bromide                  M0015691
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine   M0006747
# (+-)-isomer bupropion                            M0025361
#
#                                                                                                                                    ConceptCASN1Name  \
# (+)-isomer bay-k-8644                           3-Pyridinecarboxylic acid, 1,4-dihydro-2,6-dimethyl-5-nitro-4-(2-(trifluoromethyl)phenyl)-, meth...
# (+)-isomer methoxyhydroxyphenylglycol                                                                1,2-Ethanediol, 1-(4-hydroxy-3-methoxyphenyl)-
# (+)-isomer oxyphenonium bromide                                          Ethanaminium, 2-((cyclohexylhydroxyphenylacetyl)oxy)-N,N-diethyl-N-methyl-
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                                   Benzeneethanamine, 2,5-dimethoxy-alpha,4-dimethyl-
# (+-)-isomer bupropion                                                                 1-Propanone, 1-(3-chlorophenyl)-2-((1,1-dimethylethyl)amino)-
#
#                                                                               ConceptNameString  \
# (+)-isomer bay-k-8644                                                    Bay-K-8644, (+)-Isomer
# (+)-isomer methoxyhydroxyphenylglycol                    Methoxyhydroxyphenylglycol, (+)-Isomer
# (+)-isomer oxyphenonium bromide                                Oxyphenonium Bromide, (+)-Isomer
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  2,5-Dimethoxy-4-Methylamphetamine, (+,-)-Isomer
# (+-)-isomer bupropion                                                    Bupropion, (+-)-Isomer
#
#                                                ConceptRegistryNumber  \
# (+)-isomer bay-k-8644                                     98791-67-4
# (+)-isomer methoxyhydroxyphenylglycol                     87171-17-3
# (+)-isomer oxyphenonium bromide                           99102-05-3
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine            26011-50-7
# (+-)-isomer bupropion                                     34911-55-2
#
#                                                ConceptRelationConcept2UI  \
# (+)-isomer bay-k-8644                                           M0330830
# (+)-isomer methoxyhydroxyphenylglycol                           M0330144
# (+)-isomer oxyphenonium bromide                                 M0329910
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                  M0330395
# (+-)-isomer bupropion                                           M0331329
#
#                                                ConceptRelationName  \
# (+)-isomer bay-k-8644                                          NRW
# (+)-isomer methoxyhydroxyphenylglycol                          REL
# (+)-isomer oxyphenonium bromide                                NRW
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                 NRW
# (+-)-isomer bupropion                                          REL
#
#                                                                                                                                    ConceptScopeNote  \
# (+)-isomer bay-k-8644                           A dihydropyridine derivative, which, in contrast to NIFEDIPINE, functions as a calcium channel a...
# (+)-isomer methoxyhydroxyphenylglycol           Synthesized from endogenous epinephrine and norepinephrine in vivo. It is found in brain, blood,...
# (+)-isomer oxyphenonium bromide                 A quaternary ammonium anticholinergic agent with peripheral side effects similar to those of ATR...
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  A psychedelic phenyl isopropylamine derivative, commonly called DOM, whose mood-altering effects...
# (+-)-isomer bupropion                           A unicyclic, aminoketone antidepressant. The mechanism of its therapeutic actions is not well un...
#
#                                                ConceptTermList ConceptUI  \
# (+)-isomer bay-k-8644                                  \n       M0330830
# (+)-isomer methoxyhydroxyphenylglycol                  \n       M0330144
# (+)-isomer oxyphenonium bromide                        \n       M0329910
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine         \n       M0330395
# (+-)-isomer bupropion                                  \n       M0331329
#
#                                                 DateCreatedDay  \
# (+)-isomer bay-k-8644                                       13
# (+)-isomer methoxyhydroxyphenylglycol                       13
# (+)-isomer oxyphenonium bromide                             13
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine              13
# (+-)-isomer bupropion                                       13
#
#                                                 DateCreatedMonth  \
# (+)-isomer bay-k-8644                                          9
# (+)-isomer methoxyhydroxyphenylglycol                          9
# (+)-isomer oxyphenonium bromide                                9
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                 9
# (+-)-isomer bupropion                                          9
#
#                                                 DateCreatedYear  \
# (+)-isomer bay-k-8644                                      1999
# (+)-isomer methoxyhydroxyphenylglycol                      1999
# (+)-isomer oxyphenonium bromide                            1999
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             1999
# (+-)-isomer bupropion                                      1999
#
#                                                 DateEstablishedDay  \
# (+)-isomer bay-k-8644                                            1
# (+)-isomer methoxyhydroxyphenylglycol                            1
# (+)-isomer oxyphenonium bromide                                  1
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                   1
# (+-)-isomer bupropion                                            1
#
#                                                 DateEstablishedMonth  \
# (+)-isomer bay-k-8644                                              1
# (+)-isomer methoxyhydroxyphenylglycol                              1
# (+)-isomer oxyphenonium bromide                                    1
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                     1
# (+-)-isomer bupropion                                              1
#
#                                                 DateEstablishedYear  \
# (+)-isomer bay-k-8644                                          1987
# (+)-isomer methoxyhydroxyphenylglycol                          1991
# (+)-isomer oxyphenonium bromide                                1991
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                 1991
# (+-)-isomer bupropion                                          1992
#
#                                                 DateRevisedDay  \
# (+)-isomer bay-k-8644                                     27.0
# (+)-isomer methoxyhydroxyphenylglycol                     25.0
# (+)-isomer oxyphenonium bromide                            8.0
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine            28.0
# (+-)-isomer bupropion                                      1.0
#
#                                                 DateRevisedMonth  \
# (+)-isomer bay-k-8644                                        5.0
# (+)-isomer methoxyhydroxyphenylglycol                        7.0
# (+)-isomer oxyphenonium bromide                              7.0
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine               6.0
# (+-)-isomer bupropion                                        7.0
#
#                                                 DateRevisedYear  \
# (+)-isomer bay-k-8644                                    2016.0
# (+)-isomer methoxyhydroxyphenylglycol                    2001.0
# (+)-isomer oxyphenonium bromide                          2013.0
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine           2010.0
# (+-)-isomer bupropion                                    2016.0
#
#                                                               DescriptorNameString  \
# (+)-isomer bay-k-8644                                     Calcium Channel Agonists
# (+)-isomer methoxyhydroxyphenylglycol                   Methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                             Muscarinic Antagonists
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine         Serotonin Receptor Agonists
# (+-)-isomer bupropion                           Cytochrome P-450 CYP2D6 Inhibitors
#
#                                                              DescriptorRecordAnnotation  \
# (+)-isomer bay-k-8644                                     a calcium channel agonist\n
# (+)-isomer methoxyhydroxyphenylglycol                                              None
# (+)-isomer oxyphenonium bromide                                                    None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                     None
# (+-)-isomer bupropion                           do not confuse with Zyban fungicide\n
#
#                                                DescriptorRecordConsiderAlso  \
# (+)-isomer bay-k-8644                                                  None
# (+)-isomer methoxyhydroxyphenylglycol                                  None
# (+)-isomer oxyphenonium bromide                                        None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                         None
# (+-)-isomer bupropion                                                  None
#
#                                                DescriptorRecordDescriptorUI  \
# (+)-isomer bay-k-8644                                               D001498
# (+)-isomer methoxyhydroxyphenylglycol                               D008734
# (+)-isomer oxyphenonium bromide                                     D010115
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                      D004290
# (+-)-isomer bupropion                                               D016642
#
#                                                DescriptorRecordEntryCombinationList  \
# (+)-isomer bay-k-8644                                                          None
# (+)-isomer methoxyhydroxyphenylglycol                                          None
# (+)-isomer oxyphenonium bromide                                                None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                 None
# (+-)-isomer bupropion                                                          None
#
#                                                                                                                         DescriptorRecordHistoryNote  \
# (+)-isomer bay-k-8644                                                                                                                        87\n
# (+)-isomer methoxyhydroxyphenylglycol           91(77); was see under GLYCOLS 1977-90; was METHOXYHYDROXYPHENYL GLYCOL see under GLYCOLS 1975-76...
# (+)-isomer oxyphenonium bromide                                 92(64); was OXYPHENONIUM BROMIDE 1964-91 (see under AMMONIUM COMPOUNDS 1964-90)\n
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                                                                       2001(1973)\n
# (+-)-isomer bupropion                                                                                            92; was BUPROPION (NM) 1978-91\n
#
#                                                DescriptorRecordNLMClassificationNumber  \
# (+)-isomer bay-k-8644                                                             None
# (+)-isomer methoxyhydroxyphenylglycol                                            QV 82
# (+)-isomer oxyphenonium bromide                                                   None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                    None
# (+-)-isomer bupropion                                                             None
#
#                                                                                                                         DescriptorRecordOnlineNote  \
# (+)-isomer bay-k-8644                                                                                                                         None
# (+)-isomer methoxyhydroxyphenylglycol           use METHOXYHYDROXYPHENYLGLYCOL to search METHOXYHYDROXYPHENYL GLYCOL 1973-76 (as Prov 1973-74)\n
# (+)-isomer oxyphenonium bromide                                                        use OXYPHENONIUM to search OXYPHENONIUM BROMIDE 1966-91\n
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                                                                                None
# (+-)-isomer bupropion                                                                           use BUPROPION (NM) to search BUPROPION 1980-91\n
#
#                                                                                                                   DescriptorRecordPublicMeSHNote  \
# (+)-isomer bay-k-8644                                                                                                                     87\n
# (+)-isomer methoxyhydroxyphenylglycol           91; was see under GLYCOLS 1977-90; was METHOXYHYDROXYPHENYL GLYCOL see under GLYCOLS 1975-76\n
# (+)-isomer oxyphenonium bromide                                  92; was OXYPHENONIUM BROMIDE 1964-91 (see under AMMONIUM COMPOUNDS 1964-90)\n
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                                2001; see DOM 1991-2000 & AMPHETAMINES 1973-90\n
# (+-)-isomer bupropion                                                                 92; BUPROPION was indexed under PROPIOPHENONES 1978-91\n
#
#                                                DescriptorRecordSeeRelatedList  \
# (+)-isomer bay-k-8644                                                    None
# (+)-isomer methoxyhydroxyphenylglycol                                    None
# (+)-isomer oxyphenonium bromide                                          None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           None
# (+-)-isomer bupropion                                                   \n
#
#                                                DescriptorReferredTo  \
# (+)-isomer bay-k-8644                                          None
# (+)-isomer methoxyhydroxyphenylglycol                          None
# (+)-isomer oxyphenonium bromide                                None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                 None
# (+-)-isomer bupropion                                       \n
#
#                                                DescriptorReferredToDescriptorUI  \
# (+)-isomer bay-k-8644                                                   D002120
# (+)-isomer methoxyhydroxyphenylglycol                                      None
# (+)-isomer oxyphenonium bromide                                         D018727
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                          D017366
# (+-)-isomer bupropion                                                   D065690
#
#                                                          DescriptorStringProcessed  \
# (+)-isomer bay-k-8644                                     calcium channel agonists
# (+)-isomer methoxyhydroxyphenylglycol                   methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                             muscarinic antagonists
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine         serotonin receptor agonists
# (+-)-isomer bupropion                           cytochrome p-450 cyp2d6 inhibitors
#
#                                                EntryCombination  \
# (+)-isomer bay-k-8644                                      None
# (+)-isomer methoxyhydroxyphenylglycol                      None
# (+)-isomer oxyphenonium bromide                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             None
# (+-)-isomer bupropion                                      None
#
#                                                IsPermutedTermYN  \
# (+)-isomer bay-k-8644                                         N
# (+)-isomer methoxyhydroxyphenylglycol                         N
# (+)-isomer oxyphenonium bromide                               N
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                N
# (+-)-isomer bupropion                                         N
#
#                                                PreferredConceptYN  \
# (+)-isomer bay-k-8644                                           N
# (+)-isomer methoxyhydroxyphenylglycol                           N
# (+)-isomer oxyphenonium bromide                                 N
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                  N
# (+-)-isomer bupropion                                           N
#
#                                                PreferredTermYN  \
# (+)-isomer bay-k-8644                                        Y
# (+)-isomer methoxyhydroxyphenylglycol                        Y
# (+)-isomer oxyphenonium bromide                              Y
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine               Y
# (+-)-isomer bupropion                                        Y
#
#                                                                 PreviousIndexing  \
# (+)-isomer bay-k-8644                                      Pyridines (1966-1974)
# (+)-isomer methoxyhydroxyphenylglycol                        Glycols (1966-1974)
# (+)-isomer oxyphenonium bromide                 Oxyphenonium Bromide (1966-1991)
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                              None
# (+-)-isomer bupropion                                 Propiophenones (1966-1991)
#
#                                                QualifierAbbreviation  \
# (+)-isomer bay-k-8644                                             TO
# (+)-isomer methoxyhydroxyphenylglycol                             TO
# (+)-isomer oxyphenonium bromide                                   TO
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                    TO
# (+-)-isomer bupropion                                             TO
#
#                                                QualifierNameString  \
# (+)-isomer bay-k-8644                                     toxicity
# (+)-isomer methoxyhydroxyphenylglycol                     toxicity
# (+)-isomer oxyphenonium bromide                           toxicity
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine            toxicity
# (+-)-isomer bupropion                                     toxicity
#
#                                                QualifierReferredToQualifierUI  \
# (+)-isomer bay-k-8644                                                 Q000633
# (+)-isomer methoxyhydroxyphenylglycol                                 Q000633
# (+)-isomer oxyphenonium bromide                                       Q000633
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                        Q000633
# (+-)-isomer bupropion                                                 Q000633
#
#                                                        RelatedRegistryNumber  \
# (+)-isomer bay-k-8644                                98791-67-4 ((+)-isomer)
# (+)-isomer methoxyhydroxyphenylglycol                87171-18-4 ((-)-isomer)
# (+)-isomer oxyphenonium bromide                                   S9421HWB3Z
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  50505-89-0 ((S)-isomer, HCl)
# (+-)-isomer bupropion                                             ZG7E5POY8O
#
#                                                 RootDescriptorClass  \
# (+)-isomer bay-k-8644                                             1
# (+)-isomer methoxyhydroxyphenylglycol                             1
# (+)-isomer oxyphenonium bromide                                   1
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                    1
# (+-)-isomer bupropion                                             1
#
#                                                SeeRelatedDescriptor  \
# (+)-isomer bay-k-8644                                          None
# (+)-isomer methoxyhydroxyphenylglycol                          None
# (+)-isomer oxyphenonium bromide                                None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                 None
# (+-)-isomer bupropion                                        \n
#
#                                                TermEntryVersion  \
# (+)-isomer bay-k-8644                                      None
# (+)-isomer methoxyhydroxyphenylglycol                      None
# (+)-isomer oxyphenonium bromide                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             None
# (+-)-isomer bupropion                                      None
#
#                                                TermListLexicalTag  \
# (+)-isomer bay-k-8644                                         NON
# (+)-isomer methoxyhydroxyphenylglycol                         NON
# (+)-isomer oxyphenonium bromide                               NON
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                NON
# (+-)-isomer bupropion                                         NON
#
#                                                TermListRecordPreferredTermYN  \
# (+)-isomer bay-k-8644                                                      N
# (+)-isomer methoxyhydroxyphenylglycol                                      N
# (+)-isomer oxyphenonium bromide                                            N
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                             N
# (+-)-isomer bupropion                                                      N
#
#                                                                                                                                     TermSortVersion  \
# (+)-isomer bay-k-8644                           PYRIDINECARBOXYLIC ACID 03 1 4 DIHYDRO 2 6 DIMETHYL 5 NITRO 4 2 TRIFLUOROMETHYL PHENYL METHYL ESTER
# (+)-isomer methoxyhydroxyphenylglycol                                                                                                          None
# (+)-isomer oxyphenonium bromide                                                                                                                None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                                                  DIMETHOXYMETHYLAMPHETAMINE 02 05 04
# (+-)-isomer bupropion                                                                                                                          None
#
#                                                                                      TermString  \
# (+)-isomer bay-k-8644                                                    Bay-K-8644, (+)-Isomer
# (+)-isomer methoxyhydroxyphenylglycol                    Methoxyhydroxyphenylglycol, (+)-Isomer
# (+)-isomer oxyphenonium bromide                                Oxyphenonium Bromide, (+)-Isomer
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  2,5-Dimethoxy-4-Methylamphetamine, (+,-)-Isomer
# (+-)-isomer bupropion                                                    Bupropion, (+-)-Isomer
#
#                                                                            TermStringProcessed  \
# (+)-isomer bay-k-8644                                                    (+)-isomer bay-k-8644
# (+)-isomer methoxyhydroxyphenylglycol                    (+)-isomer methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                                (+)-isomer oxyphenonium bromide
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine
# (+-)-isomer bupropion                                                    (+-)-isomer bupropion
#
#                                                TermTermUI ThesaurusID  \
# (+)-isomer bay-k-8644                             T361024  NLM (1999)
# (+)-isomer methoxyhydroxyphenylglycol             T360338  NLM (1999)
# (+)-isomer oxyphenonium bromide                   T360104  NLM (1999)
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine    T360589  NLM (1999)
# (+-)-isomer bupropion                             T361523  NLM (1999)
#
#                                                              TreeNumber  \
# (+)-isomer bay-k-8644                               D03.383.725.547.900
# (+)-isomer methoxyhydroxyphenylglycol               D02.033.455.250.610
# (+)-isomer oxyphenonium bromide                         D02.675.276.648
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  D02.092.471.683.152.391
# (+-)-isomer bupropion                                   D02.522.818.110
#
#                                                tree_ConceptStringProcessed_1  \
# (+)-isomer bay-k-8644                                 heterocyclic compounds
# (+)-isomer methoxyhydroxyphenylglycol                      organic chemicals
# (+)-isomer oxyphenonium bromide                            organic chemicals
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             organic chemicals
# (+-)-isomer bupropion                                      organic chemicals
#
#                                                tree_ConceptStringProcessed_10  \
# (+)-isomer bay-k-8644                                                    None
# (+)-isomer methoxyhydroxyphenylglycol                                    None
# (+)-isomer oxyphenonium bromide                                          None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           None
# (+-)-isomer bupropion                                                    None
#
#                                                tree_ConceptStringProcessed_11  \
# (+)-isomer bay-k-8644                                                    None
# (+)-isomer methoxyhydroxyphenylglycol                                    None
# (+)-isomer oxyphenonium bromide                                          None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           None
# (+-)-isomer bupropion                                                    None
#
#                                                 tree_ConceptStringProcessed_12  \
# (+)-isomer bay-k-8644                                                      NaN
# (+)-isomer methoxyhydroxyphenylglycol                                      NaN
# (+)-isomer oxyphenonium bromide                                            NaN
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                             NaN
# (+-)-isomer bupropion                                                      NaN
#
#                                                 tree_ConceptStringProcessed_2  \
# (+)-isomer bay-k-8644                           1-ring heterocyclic compounds
# (+)-isomer methoxyhydroxyphenylglycol                                alcohols
# (+)-isomer oxyphenonium bromide                               onium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                         amines
# (+-)-isomer bupropion                                                 ketones
#
#                                                 tree_ConceptStringProcessed_3  \
# (+)-isomer bay-k-8644                                               pyridines
# (+)-isomer methoxyhydroxyphenylglycol                                 glycols
# (+)-isomer oxyphenonium bromide                 quaternary ammonium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                    ethylamines
# (+-)-isomer bupropion                                          propiophenones
#
#                                                   tree_ConceptStringProcessed_4  \
# (+)-isomer bay-k-8644                                           nicotinic acids
# (+)-isomer methoxyhydroxyphenylglycol                          ethylene glycols
# (+)-isomer oxyphenonium bromide                 (+)-isomer oxyphenonium bromide
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                  phenethylamines
# (+-)-isomer bupropion                                     (+-)-isomer bupropion
#
#                                                         tree_ConceptStringProcessed_5  \
# (+)-isomer bay-k-8644                                           (+)-isomer bay-k-8644
# (+)-isomer methoxyhydroxyphenylglycol           (+)-isomer methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                                                  None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           amphetamines
# (+-)-isomer bupropion                                                            None
#
#                                                                  tree_ConceptStringProcessed_6  \
# (+)-isomer bay-k-8644                                                                     None
# (+)-isomer methoxyhydroxyphenylglycol                                                     None
# (+)-isomer oxyphenonium bromide                                                           None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine
# (+-)-isomer bupropion                                                                     None
#
#                                                tree_ConceptStringProcessed_7  \
# (+)-isomer bay-k-8644                                                   None
# (+)-isomer methoxyhydroxyphenylglycol                                   None
# (+)-isomer oxyphenonium bromide                                         None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                          None
# (+-)-isomer bupropion                                                   None
#
#                                                tree_ConceptStringProcessed_8  \
# (+)-isomer bay-k-8644                                                   None
# (+)-isomer methoxyhydroxyphenylglycol                                   None
# (+)-isomer oxyphenonium bromide                                         None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                          None
# (+-)-isomer bupropion                                                   None
#
#                                                tree_ConceptStringProcessed_9  \
# (+)-isomer bay-k-8644                                                   None
# (+)-isomer methoxyhydroxyphenylglycol                                   None
# (+)-isomer oxyphenonium bromide                                         None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                          None
# (+-)-isomer bupropion                                                   None
#
#                                                tree_DescriptorStringProcessed_1  \
# (+)-isomer bay-k-8644                                    heterocyclic compounds
# (+)-isomer methoxyhydroxyphenylglycol                         organic chemicals
# (+)-isomer oxyphenonium bromide                               organic chemicals
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                organic chemicals
# (+-)-isomer bupropion                                         organic chemicals
#
#                                                tree_DescriptorStringProcessed_10  \
# (+)-isomer bay-k-8644                                                       None
# (+)-isomer methoxyhydroxyphenylglycol                                       None
# (+)-isomer oxyphenonium bromide                                             None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                              None
# (+-)-isomer bupropion                                                       None
#
#                                                tree_DescriptorStringProcessed_11  \
# (+)-isomer bay-k-8644                                                       None
# (+)-isomer methoxyhydroxyphenylglycol                                       None
# (+)-isomer oxyphenonium bromide                                             None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                              None
# (+-)-isomer bupropion                                                       None
#
#                                                 tree_DescriptorStringProcessed_12  \
# (+)-isomer bay-k-8644                                                         NaN
# (+)-isomer methoxyhydroxyphenylglycol                                         NaN
# (+)-isomer oxyphenonium bromide                                               NaN
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                                NaN
# (+-)-isomer bupropion                                                         NaN
#
#                                                tree_DescriptorStringProcessed_2  \
# (+)-isomer bay-k-8644                             1-ring heterocyclic compounds
# (+)-isomer methoxyhydroxyphenylglycol                                  alcohols
# (+)-isomer oxyphenonium bromide                                 onium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           amines
# (+-)-isomer bupropion                                                   ketones
#
#                                                tree_DescriptorStringProcessed_3  \
# (+)-isomer bay-k-8644                                               piperidines
# (+)-isomer methoxyhydroxyphenylglycol                                   glycols
# (+)-isomer oxyphenonium bromide                           quinolinium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                      ethylamines
# (+-)-isomer bupropion                                            propiophenones
#
#                                                   tree_DescriptorStringProcessed_4  \
# (+)-isomer bay-k-8644                                            vitamin b complex
# (+)-isomer methoxyhydroxyphenylglycol                             ethylene glycols
# (+)-isomer oxyphenonium bromide                             muscarinic antagonists
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                     phenethylamines
# (+-)-isomer bupropion                           cytochrome p-450 cyp2d6 inhibitors
#
#                                                tree_DescriptorStringProcessed_5  \
# (+)-isomer bay-k-8644                                  calcium channel agonists
# (+)-isomer methoxyhydroxyphenylglycol                methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             appetite depressants
# (+-)-isomer bupropion                                                      None
#
#                                                tree_DescriptorStringProcessed_6  \
# (+)-isomer bay-k-8644                                                      None
# (+)-isomer methoxyhydroxyphenylglycol                                      None
# (+)-isomer oxyphenonium bromide                                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine      serotonin receptor agonists
# (+-)-isomer bupropion                                                      None
#
#                                                tree_DescriptorStringProcessed_7  \
# (+)-isomer bay-k-8644                                                      None
# (+)-isomer methoxyhydroxyphenylglycol                                      None
# (+)-isomer oxyphenonium bromide                                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                             None
# (+-)-isomer bupropion                                                      None
#
#                                                tree_DescriptorStringProcessed_8  \
# (+)-isomer bay-k-8644                                                      None
# (+)-isomer methoxyhydroxyphenylglycol                                      None
# (+)-isomer oxyphenonium bromide                                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                             None
# (+-)-isomer bupropion                                                      None
#
#                                                tree_DescriptorStringProcessed_9  \
# (+)-isomer bay-k-8644                                                      None
# (+)-isomer methoxyhydroxyphenylglycol                                      None
# (+)-isomer oxyphenonium bromide                                            None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                             None
# (+-)-isomer bupropion                                                      None
#
#                                                tree_TermStringProcessed_1  \
# (+)-isomer bay-k-8644                              heterocyclic compounds
# (+)-isomer methoxyhydroxyphenylglycol                   organic chemicals
# (+)-isomer oxyphenonium bromide                         organic chemicals
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine          organic chemicals
# (+-)-isomer bupropion                                   organic chemicals
#
#                                                tree_TermStringProcessed_10  \
# (+)-isomer bay-k-8644                                                 None
# (+)-isomer methoxyhydroxyphenylglycol                                 None
# (+)-isomer oxyphenonium bromide                                       None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                        None
# (+-)-isomer bupropion                                                 None
#
#                                                tree_TermStringProcessed_11  \
# (+)-isomer bay-k-8644                                                 None
# (+)-isomer methoxyhydroxyphenylglycol                                 None
# (+)-isomer oxyphenonium bromide                                       None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                        None
# (+-)-isomer bupropion                                                 None
#
#                                                 tree_TermStringProcessed_12  \
# (+)-isomer bay-k-8644                                                   NaN
# (+)-isomer methoxyhydroxyphenylglycol                                   NaN
# (+)-isomer oxyphenonium bromide                                         NaN
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                          NaN
# (+-)-isomer bupropion                                                   NaN
#
#                                                tree_TermStringProcessed_2  \
# (+)-isomer bay-k-8644                            1 ring heterocyclic cpds
# (+)-isomer methoxyhydroxyphenylglycol                            alcohols
# (+)-isomer oxyphenonium bromide                           onium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                     amines
# (+-)-isomer bupropion                                             ketones
#
#                                                    tree_TermStringProcessed_3  \
# (+)-isomer bay-k-8644                                               pyridines
# (+)-isomer methoxyhydroxyphenylglycol                                 glycols
# (+)-isomer oxyphenonium bromide                 quaternary ammonium compounds
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                    ethylamines
# (+-)-isomer bupropion                                          propiophenones
#
#                                                      tree_TermStringProcessed_4  \
# (+)-isomer bay-k-8644                                           nicotinic acids
# (+)-isomer methoxyhydroxyphenylglycol                               ethanediols
# (+)-isomer oxyphenonium bromide                 (+)-isomer oxyphenonium bromide
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                phenylethylamines
# (+-)-isomer bupropion                                     (+-)-isomer bupropion
#
#                                                            tree_TermStringProcessed_5  \
# (+)-isomer bay-k-8644                                           (+)-isomer bay-k-8644
# (+)-isomer methoxyhydroxyphenylglycol           (+)-isomer methoxyhydroxyphenylglycol
# (+)-isomer oxyphenonium bromide                                                  None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                           amphetamines
# (+-)-isomer bupropion                                                            None
#
#                                                                     tree_TermStringProcessed_6  \
# (+)-isomer bay-k-8644                                                                     None
# (+)-isomer methoxyhydroxyphenylglycol                                                     None
# (+)-isomer oxyphenonium bromide                                                           None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine
# (+-)-isomer bupropion                                                                     None
#
#                                                tree_TermStringProcessed_7  \
# (+)-isomer bay-k-8644                                                None
# (+)-isomer methoxyhydroxyphenylglycol                                None
# (+)-isomer oxyphenonium bromide                                      None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                       None
# (+-)-isomer bupropion                                                None
#
#                                                tree_TermStringProcessed_8  \
# (+)-isomer bay-k-8644                                                None
# (+)-isomer methoxyhydroxyphenylglycol                                None
# (+)-isomer oxyphenonium bromide                                      None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                       None
# (+-)-isomer bupropion                                                None
#
#                                                tree_TermStringProcessed_9  \
# (+)-isomer bay-k-8644                                                None
# (+)-isomer methoxyhydroxyphenylglycol                                None
# (+)-isomer oxyphenonium bromide                                      None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine                       None
# (+-)-isomer bupropion                                                None
#
#                                                tree_number_0 tree_number_1  \
# (+)-isomer bay-k-8644                                      D           D03
# (+)-isomer methoxyhydroxyphenylglycol                      D           D02
# (+)-isomer oxyphenonium bromide                            D           D02
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine             D           D02
# (+-)-isomer bupropion                                      D           D02
#
#                                                tree_number_10 tree_number_11  \
# (+)-isomer bay-k-8644                                    None           None
# (+)-isomer methoxyhydroxyphenylglycol                    None           None
# (+)-isomer oxyphenonium bromide                          None           None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine           None           None
# (+-)-isomer bupropion                                    None           None
#
#                                                tree_number_12 tree_number_2  \
# (+)-isomer bay-k-8644                                    None       D03.383
# (+)-isomer methoxyhydroxyphenylglycol                    None       D02.033
# (+)-isomer oxyphenonium bromide                          None       D02.675
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine           None       D02.092
# (+-)-isomer bupropion                                    None       D02.522
#
#                                                tree_number_3    tree_number_4  \
# (+)-isomer bay-k-8644                            D03.383.725  D03.383.725.547
# (+)-isomer methoxyhydroxyphenylglycol            D02.033.455  D02.033.455.250
# (+)-isomer oxyphenonium bromide                  D02.675.276  D02.675.276.648
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine   D02.092.471  D02.092.471.683
# (+-)-isomer bupropion                            D02.522.818  D02.522.818.110
#
#                                                       tree_number_5  \
# (+)-isomer bay-k-8644                           D03.383.725.547.900
# (+)-isomer methoxyhydroxyphenylglycol           D02.033.455.250.610
# (+)-isomer oxyphenonium bromide                                None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  D02.092.471.683.152
# (+-)-isomer bupropion                                          None
#
#                                                           tree_number_6  \
# (+)-isomer bay-k-8644                                              None
# (+)-isomer methoxyhydroxyphenylglycol                              None
# (+)-isomer oxyphenonium bromide                                    None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  D02.092.471.683.152.391
# (+-)-isomer bupropion                                              None
#
#                                                tree_number_7 tree_number_8  \
# (+)-isomer bay-k-8644                                   None          None
# (+)-isomer methoxyhydroxyphenylglycol                   None          None
# (+)-isomer oxyphenonium bromide                         None          None
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine          None          None
# (+-)-isomer bupropion                                   None          None
#
#                                                tree_number_9  tree_order  \
# (+)-isomer bay-k-8644                                   None           5
# (+)-isomer methoxyhydroxyphenylglycol                   None           5
# (+)-isomer oxyphenonium bromide                         None           4
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine          None           6
# (+-)-isomer bupropion                                   None           4
#
#                                                       tree_string_0
# (+)-isomer bay-k-8644                           chemicals and drugs
# (+)-isomer methoxyhydroxyphenylglycol           chemicals and drugs
# (+)-isomer oxyphenonium bromide                 chemicals and drugs
# (+,-)-isomer 2,5-dimethoxy-4-methylamphetamine  chemicals and drugs
# (+-)-isomer bupropion                           chemicals and drugs
