# %% [markdown]
# # RWJF open data analysis
#
# We have access to two datasets about the projects that RWJF support:
#
# 1. Pioneers dataset: Information about grants awarded as part of the Pioneers programme, which focuses on innovations in the USA
# 2. Global dataset: Grants awarsed as part of the Global programme, which focuses on innovations outside the USA
# 3. Open dataset: With information about all their grants
#
# 1 and 2 are relatively unstructured but contain rich text, whereas 3 is well structured but doesn't have a lot of text.
#
# We want to rapidly process these data and analyse them to understand:
#
# * What is RWJFs funding portfolio: what topics are they supporting? Where?
# * Enrich these data with additional information from for example GRID, CrunchBase to map collaboration networks.

# %% [markdown]
# ## Preamble

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
#NB I open a standard set of directories

#Paths
import os
import datetime

#Get the top path
top_path = os.path.dirname(os.getcwd())

#Create the path for external data
ext_data = os.path.join(top_path,'data/external')

#Raw path (for html downloads)

raw_data = os.path.join(top_path,'data/raw')

#And external data
proc_data = os.path.join(top_path,'data/processed')

fig_path = os.path.join(top_path,'reports/figures')

#Get date for saving files
today = datetime.datetime.today()

today_str = "_".join([str(x) for x in [today.day,today.month,today.year]])

# %%
#Additional imports
import ratelim

import re

import io

import urllib

import codecs

import json

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import bs4

from nltk.corpus import stopwords

stop = stopwords.words('English')

from lda_pipeline import LdaPipeline, CleanTokenize

# %% [markdown]
# ## 1. Load data

# %% [markdown]
# ### Load the Global and Pioneers data

# %%
def get_project_meta(project):
    '''
    This function takes a project and returns the name and the id 
    (if they are available, this is not always the case).
    
    '''
    
    if 'ID'  in project:
        #Split on the ID string to get the name
        name = project.split('ID')[0].strip()
        
        #Split on the ID string again to get what we want
        grant_id = re.sub('[#:]','',project.split('ID')[1].split('\n')[0].strip()).strip()

    
    else:
        #If there is no ID we split on line breaks
        name = project.strip().split('\n')[0].strip()
        grant_id = np.nan
     
    #description = project.split('\n*')[1]
    return([name,grant_id])

#def clean_up_text(project):
    


def flatten_list(my_list):
    '''
    Turns a nested list into a flat list
    
    '''
    
    flat = [x for el in my_list for x in el]
    
    return(flat)

# %%
def read_rwjf_data(file):
    '''
    This function reads project lists from the RWJF and tidies it up, and returns
    a list where each element has the project name, grant id and description
    
    '''
    #Load the data
    with open(ext_data+'/'+file, 'r') as myfile:
        data=myfile.read()
    
    #Split it based on the project separator and leave out the links at the top
    projects = data.split('\n________________\n')[1:]
    
    #Extract metadata
    project_meta = [get_project_meta(x) for x in projects]
    
    #project_descriptions = [x[2] for x in project_meta]
    
    #Clean up the project info
    projects_clean = [re.sub('\* ','',re.sub('\n','',project)).lower() for project in projects]
    
    return([[x,y,z] for x,y,z in zip(
        [x[0] for x in project_meta],
        [x[1] for x in project_meta],
        projects_clean)])

# %%
#Load both files
pio = read_rwjf_data('pioneer_grantees.txt')

glob = read_rwjf_data('global_grantees.txt')

# %%
rw_df = pd.DataFrame([x+['pioneers'] for x in pio]+[x+['global'] for x in glob],columns=['project',
                                                                                'code','description','source'])

rw_df.to_csv(proc_data+'/{date}_rwj_data_from_mike.csv'.format(date=today_str))

rw_df.head(10)
# Out:
#                                              project  \
# 0  Air Louisville (Propeller Health) (Paul Tarini...
# 1                        AARP Catalyst (David) Grant
# 2  Applying Behavioral Economics to Perplexing Pr...
# 3  Atlas of Caregiving (David Adler/Lori Melichar...
# 4                        MIT Blockchain (Mike) Grant
# 5   Brookings Well-Being Metrics (David Adler) Grant
# 6            Changing Mindsets/SPARQ (Deborah) Grant
# 7                  CDC Wearables (Paul Tarini) Grant
# 8                           Cedar Sinai (Paul) Grant
# 9                       Civic Hall Labs (Lori) Grant
#
#                                    code  \
# 0                                 71592
# 1                                 72884
# 2                                 69227
# 3                                 72411
# 4  74694 [https//medrec.media.mit.edu/]
# 5                                 74378
# 6                                 72393
# 7                                 73744
# 8                                 72399
# 9                                 73274
#
#                                          description    source
# 0  air louisville (propeller health) (paul tarini...  pioneers
# 1  aarp catalyst (david) grant id: 72884with supp...  pioneers
# 2  applying behavioral economics to perplexing pr...  pioneers
# 3  atlas of caregiving (david adler/lori melichar...  pioneers
# 4  mit blockchain (mike) grant id: 74694 [https:/...  pioneers
# 5  brookings well-being metrics (david adler) gra...  pioneers
# 6  changing mindsets/sparq (deborah) grant id: 72...  pioneers
# 7  cdc wearables (paul tarini) grant id#: 73744co...  pioneers
# 8  cedar sinai (paul) grant id: 72399over the las...  pioneers
# 9  civic hall labs (lori) grant id: 73274the new ...  pioneers

# %% [markdown]
# ### Load the RWJF open grant data

# %%
grant_data = pd.read_csv(ext_data + '/rwjf_grants.csv')

# %%
grant_data.head()
# Out:
#                                                Title  \
# 0  Technical assistance and direction for New Con...
# 1  Building on the Federal-State Implementation P...
# 2  Building on the track record and expanding ser...
# 3  Supporting research to guide positive dietary ...
# 4  Planning for possible expansion of the health-...
#
#                                         Organization           Location  \
# 0                                      Equal Measure   Philadelphia, PA
# 1                   Jennings Policy Strategies, Inc.     Washington, DC
# 2  University of California, San Francisco, Cente...  San Francisco, CA
# 3  American Association of Retired Persons Founda...     Washington, DC
# 4                              Pew Charitable Trusts   Philadelphia, PA
#
#    Awarded Amount  Year                                             Topics
# 0         1167854  2018                    [Health Leadership Development]
# 1          237500  2018                                  [Health Coverage]
# 2         1399200  2018  [Early Childhood Development, Health Care Qual...
# 3           48000  2018     [Childhood Obesity, Family and Social Support]
# 4          195600  2018  [Disease Prevention and Health Promotion, Heal...

# %%
#Unfortunately they don't have the grant ids in their open dataset! 

pd.Series(flatten_list([[y for y in x[2].split(' ') if y not in stop] for x in pio])).value_counts()[:10]
# Out:
#                 1688
# health           329
# data             130
# grant             95
# help              81
# care              70
# description:      68
# research          67
# improve           65
# people            65
# dtype: int64

# %% [markdown]
# ## Load the RWJF scraped data

# %%
with open(ext_data+'/11_4_2018_rwjf_scraped.json','r') as infile:
    rwf = json.load(infile)
    
r_df_messy = pd.concat([pd.Series(x) for x in rwf],axis=1).T

# %%
#This is what the data looks like. Note the presence of 'Nones' which we want to turn into nans and
# line breaks \n which we want to turn into spaces
#NB also the presence of apparently redundant columns. How is amount_awarded different from awarded?
r_df_messy.head()
# Out:
#                                                about  \
# 0  To create, publish, and distribute a future-fi...
# 1  To produce two books about U.S. health issues ...
# 2  To (1) help develop the WinWinWiki, a standard...
# 3  To launch the Change in Mind Institute to prov...
# 4  To continue dissemination and analytical activ...
#
#                                              address amount_awarded   awarded  \
# 0  Melcher Media, Inc.\nGarden Level\n124 West 13...       $393,900  $393,900
# 1  Columbia University\n630 West 168th Street\nNe...       $250,000  $250,000
# 2  WinWin Collective (The Seattle Foundation as f...       $350,000  $350,000
# 3  Alliance for Strong Families and Communities, ...       $500,000  $500,000
# 4  Milliman, Inc.\n1301 Fifth Avenue, Suite 3800\...       $250,000  $250,000
#
#   awarded_on contacts grant_number       location  \
# 0  1/17/2018                 74714   New York, NY
# 1   1/5/2018                 74887   New York, NY
# 2  12/2/2017                 74910    Seattle, WA
# 3  12/1/2017                 74968  Milwaukee, WI
# 4   1/8/2018                 74977    Seattle, WA
#
#                                         organization page  \
# 0                                Melcher Media, Inc.   21
# 1                                Columbia University   23
# 2  WinWin Collective (The Seattle Foundation as f...   41
# 3  Alliance for Strong Families and Communities, ...   41
# 4                                     Milliman, Inc.   23
#
#                 timeframe                                              title  \
# 0  10/15/2017 - 9/14/2018  Publishing a print and e-book anthology by pro...
# 1   1/1/2018 - 12/31/2019  Supporting publication of two Columbia Global ...
# 2  12/1/2017 - 11/30/2018  Implementing the WinWin ecosystem in Essex Cou...
# 3   1/1/2018 - 12/31/2018  Launching the Change in Mind Institute to appl...
# 4   11/1/2017 - 4/30/2018  Providing actuarial analyses and modeling of h...
#
#                                               topics  \
# 0                                               None
# 1                                               None
# 2  Disease Prevention and Health Promotion\nBuilt...
# 3                                               None
# 4                                    Health Coverage
#
#                      website  year
# 0        http://melcher.com/  2018
# 1   http://www.columbia.edu/  2018
# 2    http://www.winwin.care/  2017
# 3  http://www.alliance1.org/  2017
# 4   http://www.milliman.com/  2018

# %%
#Get the type of each class. They are mostly strings. We will need to convert the awarded to floats,
#Timeframe or awarded on to dates and so forth.
r_df_messy.dropna(axis=0).iloc[0,:].apply(lambda x: type(x))
# Out:
# about             <class 'str'>
# address           <class 'str'>
# amount_awarded    <class 'str'>
# awarded           <class 'str'>
# awarded_on        <class 'str'>
# contacts          <class 'str'>
# grant_number      <class 'str'>
# location          <class 'str'>
# organization      <class 'str'>
# page              <class 'int'>
# timeframe         <class 'str'>
# title             <class 'str'>
# topics            <class 'str'>
# website           <class 'str'>
# year              <class 'str'>
# Name: 2, dtype: object

# %%
#Just checking the formats. Looks like the minimum value that RWJ funds is $50K
r_df_messy.apply(lambda x: x.describe())
# Out:
#                                                     about  \
# count                                                 176
# unique                                                157
# top     To build state and national momentum to revers...
# freq                                                    7
#
#                                                   address amount_awarded  \
# count                                                 227            227
# unique                                                207            150
# top     Mathematica Policy Research, Inc.\n600 Alexand...       $150,000
# freq                                                    5             18
#
#          awarded  awarded_on contacts grant_number        location  \
# count        227         227      227          227             227
# unique       150          77       97          227              88
# top     $150,000  12/13/2017                 75144  Washington, DC
# freq          18           8      131            1              37
#
#                              organization  page               timeframe  \
# count                                 227   227                     227
# unique                                207    46                      88
# top     Mathematica Policy Research, Inc.    46  12/1/2017 - 11/30/2018
# freq                                    5     5                      20
#
#                                                     title  \
# count                                                 227
# unique                                                227
# top     Assisting Bridging for Health communities move...
# freq                                                    1
#
#                                                    topics  \
# count                                                 197
# unique                                                 89
# top     Nurses and Nursing\nHealth Leadership Development
# freq                                                   15
#
#                                 website  year
# count                               221   227
# unique                              201     2
# top     http://www.mathematica-mpr.com/  2018
# freq                                  5   119

# %%
#Tidying up. Add missing values
r_df_messy = r_df_messy.applymap(lambda x: np.nan if (x==None) | (x=='') else x)

#Remove \n 
#r_df_messy = r_df_messy.applymap(lambda x: re.sub('\n',' ',x) if type(x)==str else x)

#This is what it looks like now
r_df_messy.head()
# Out:
#                                                about  \
# 0  To create, publish, and distribute a future-fi...
# 1  To produce two books about U.S. health issues ...
# 2  To (1) help develop the WinWinWiki, a standard...
# 3  To launch the Change in Mind Institute to prov...
# 4  To continue dissemination and analytical activ...
#
#                                              address amount_awarded   awarded  \
# 0  Melcher Media, Inc.\nGarden Level\n124 West 13...       $393,900  $393,900
# 1  Columbia University\n630 West 168th Street\nNe...       $250,000  $250,000
# 2  WinWin Collective (The Seattle Foundation as f...       $350,000  $350,000
# 3  Alliance for Strong Families and Communities, ...       $500,000  $500,000
# 4  Milliman, Inc.\n1301 Fifth Avenue, Suite 3800\...       $250,000  $250,000
#
#   awarded_on contacts grant_number       location  \
# 0  1/17/2018      NaN        74714   New York, NY
# 1   1/5/2018      NaN        74887   New York, NY
# 2  12/2/2017      NaN        74910    Seattle, WA
# 3  12/1/2017      NaN        74968  Milwaukee, WI
# 4   1/8/2018      NaN        74977    Seattle, WA
#
#                                         organization  page  \
# 0                                Melcher Media, Inc.    21
# 1                                Columbia University    23
# 2  WinWin Collective (The Seattle Foundation as f...    41
# 3  Alliance for Strong Families and Communities, ...    41
# 4                                     Milliman, Inc.    23
#
#                 timeframe                                              title  \
# 0  10/15/2017 - 9/14/2018  Publishing a print and e-book anthology by pro...
# 1   1/1/2018 - 12/31/2019  Supporting publication of two Columbia Global ...
# 2  12/1/2017 - 11/30/2018  Implementing the WinWin ecosystem in Essex Cou...
# 3   1/1/2018 - 12/31/2018  Launching the Change in Mind Institute to appl...
# 4   11/1/2017 - 4/30/2018  Providing actuarial analyses and modeling of h...
#
#                                               topics  \
# 0                                                NaN
# 1                                                NaN
# 2  Disease Prevention and Health Promotion\nBuilt...
# 3                                                NaN
# 4                                    Health Coverage
#
#                      website  year
# 0        http://melcher.com/  2018
# 1   http://www.columbia.edu/  2018
# 2    http://www.winwin.care/  2017
# 3  http://www.alliance1.org/  2017
# 4   http://www.milliman.com/  2018

# %%
def get_year(date_string):
    '''
    Extracts the year from a date string
    '''
    
    year = int(date_string.split('/')[-1]) if type(date_string)==str else np.nan
    return(year)

# %%
#Here we convert the amounts awarded to numbers, the awarded dates and start dates to dates.

r_df_messy['amount_awarded_$'] = r_df_messy['amount_awarded'].apply(lambda x: 
                                                                  int(re.sub(r'[$,]','',x)) if type(x)==str else np.nan)

r_df_messy['awarded_$'] = r_df_messy['awarded'].apply(lambda x: 
                                                                  int(re.sub(r'[$,]','',x)) if type(x)==str else np.nan)

#Topics
r_df_messy['topics'] = r_df_messy['topics'].apply(lambda x: x.split('\n') if type(x)==str else np.nan)

#Years are strings
r_df_messy['year'] = r_df_messy['year'].apply(lambda x: int(x) if type(x)==str else np.nan)

# %%
#Select variables
selected_variables = ['grant_number',
            'title','about','topics',
            'organization','address','website','location',
            'year','amount_awarded_$','awarded_$',]


rwj = r_df_messy[selected_variables]

# %%
rwj.head()
# Out:
#   grant_number                                              title  \
# 0        74714  Publishing a print and e-book anthology by pro...
# 1        74887  Supporting publication of two Columbia Global ...
# 2        74910  Implementing the WinWin ecosystem in Essex Cou...
# 3        74968  Launching the Change in Mind Institute to appl...
# 4        74977  Providing actuarial analyses and modeling of h...
#
#                                                about  \
# 0  To create, publish, and distribute a future-fi...
# 1  To produce two books about U.S. health issues ...
# 2  To (1) help develop the WinWinWiki, a standard...
# 3  To launch the Change in Mind Institute to prov...
# 4  To continue dissemination and analytical activ...
#
#                                               topics  \
# 0                                                NaN
# 1                                                NaN
# 2  [Disease Prevention and Health Promotion, Buil...
# 3                                                NaN
# 4                                  [Health Coverage]
#
#                                         organization  \
# 0                                Melcher Media, Inc.
# 1                                Columbia University
# 2  WinWin Collective (The Seattle Foundation as f...
# 3  Alliance for Strong Families and Communities, ...
# 4                                     Milliman, Inc.
#
#                                              address  \
# 0  Melcher Media, Inc.\nGarden Level\n124 West 13...
# 1  Columbia University\n630 West 168th Street\nNe...
# 2  WinWin Collective (The Seattle Foundation as f...
# 3  Alliance for Strong Families and Communities, ...
# 4  Milliman, Inc.\n1301 Fifth Avenue, Suite 3800\...
#
#                      website       location  year  amount_awarded_$  awarded_$
# 0        http://melcher.com/   New York, NY  2018            393900     393900
# 1   http://www.columbia.edu/   New York, NY  2018            250000     250000
# 2    http://www.winwin.care/    Seattle, WA  2017            350000     350000
# 3  http://www.alliance1.org/  Milwaukee, WI  2017            500000     500000
# 4   http://www.milliman.com/    Seattle, WA  2018            250000     250000

# %% [markdown]
# ## 2. Exploratory data analysis
#
# Let's learn more about these data:
#
# * What do different variables mean?
# * What are the trends in terms of activity?
# * What organisations are being funded?
# * In what topics?

# %% [markdown]
# ### What do the financials mean?

# %%
#Amount awarded is present in almost all cases. Is it the same as awarded?
rwj[['amount_awarded_$','awarded_$']].describe()
# Out:
#        amount_awarded_$     awarded_$
# count      2.270000e+02  2.270000e+02
# mean       5.086912e+05  5.086912e+05
# std        7.814076e+05  7.814076e+05
# min        1.000000e+04  1.000000e+04
# 25%        1.100800e+05  1.100800e+05
# 50%        2.500000e+05  2.500000e+05
# 75%        4.995700e+05  4.995700e+05
# max        4.353228e+06  4.353228e+06

# %%
#Let's plot this
ax = plt.scatter(rwj['amount_awarded_$'],rwj['awarded_$'],alpha=0.5,color='blue')
ax.title = 'Amounts awarded vs Awarded'

# %% [markdown]
# TODO: Determine what's happening with these two figures

# %% [markdown]
# ### What is the situation with missing values?

# %%
def missing_props(df,ct=None):
    '''
    Utility function which takes a df and returns missing values in each variable as a % of total.
    If ct!= None this is a variable to crosstab the missing data against
    
    '''
    if ct==None:
        missing = np.round(100*df.apply(lambda x: np.sum(x.isna()))/len(df),3)
        
    if ct!=None:
        missing = {var: df.groupby(ct)[var].apply(lambda x: np.mean(x.isna())) for var in df.columns}
    
    return(missing)

# %%
#Plot missing values
missing_props(rwj).sort_values(ascending=False).plot.bar(color='blue',
                                                               title='Missing values (%) by variable')

# %%
fig,ax = plt.subplots(nrows=3,figsize=(8,8),sharex=True,sharey=True)

missing_props(rwj,'year')['about'].plot.bar(color='blue',ax=ax[0],title='about')
missing_props(rwj,'year')['website'].plot.bar(color='blue',ax=ax[1],title='website')
missing_props(rwj,'year')['topics'].plot.bar(color='blue',ax=ax[2],title='topics')

# %% [markdown]
# `About` coverage is not so good. `Website` coverage improves in the last 10 years.
# `topics` coverage has a more or less constant missing rate
#
# **Implications** for now: If we wanted to do an analysis using website data we would need to focus in 2010s or explore sources of bias before 2010.

# %% [markdown]
# ### Some trends

# %%
# Number of projects and amounts awarded (including our two measures)

#Create a table with totals raised by year
raised = pd.concat([rwj['year'].value_counts(),rwj.groupby('year')[['amount_awarded_$','awarded_$']].sum()],axis=1)

raised['awarded_per_project'] = raised['awarded_$']/raised['year']

#Plot
fig,ax = plt.subplots(figsize=(8,10),
                      #sharex=True,
                      nrows=4)

raised['year'].plot(ax=ax[0],title='Project count',color='blue')
raised['amount_awarded_$'].plot(ax=ax[1],title='Amount awarded ($)',color='blue')
raised['awarded_$'].plot(ax=ax[2],title='Awarded ($)',color='blue')
raised['awarded_per_project'].plot.bar(ax=ax[3],title='Awarded per project $',color='blue')

[axis.get_xaxis().set_visible(False) for axis in [ax[0],ax[1],ax[2]]]
# Out:
# [None, None, None]

# %%
#Very strong correlation between years
raised.corr(method='pearson')
# Out:
#                      year  amount_awarded_$  awarded_$  awarded_per_project
# year                  1.0              -1.0       -1.0                 -1.0
# amount_awarded_$     -1.0               1.0        1.0                  1.0
# awarded_$            -1.0               1.0        1.0                  1.0
# awarded_per_project  -1.0               1.0        1.0                  1.0

# %% [markdown]
# No clear trend in activity. `amount_awarded` and `awarded` have a very strong correlation. They are picking up the same variable

# %% [markdown]
# ### Top organisations and domains. This will be important for the scraping analysis

# %%
#What are the most 'popular' organisations in the data in terms of number of projects and 
# amounts raised?

#Create a df with the counts / totals raised
org_activity = pd.concat([rwj['organization'].value_counts(),
                          rwj.groupby('organization')['awarded_$'].sum()],axis=1)

#Sort values by number of projects
top_organisations = org_activity.sort_values('organization')[-30:]


#plot
fig,ax = plt.subplots(ncols=2,figsize=(8,8),sharey=True)

top_organisations['organization'].plot.barh(ax=ax[0],color='blue')
top_organisations['awarded_$'].plot.barh(ax=ax[1],color='blue')

# %% [markdown]
# Lots of schools of public health and universities. We can look for similar initiatives / groups in other datasets?

# %%
#These are the top websites
rwj['website'].value_counts()[:20]
# Out:
# http://www.hsph.harvard.edu/         134
# http://www.rand.org/                 107
# http://www.mathematica-mpr.com/      105
# http://www.urban.org/                103
# http://www.nationalacademies.org/     93
# http://www.sph.umn.edu/               88
# http://www.ucla.edu/                  84
# http://www.sph.umich.edu/             82
# http://www.phi.org/                   81
# http://www.med.wisc.edu/              78
# http://publichealth.gwu.edu/          77
# http://www.foundationofumdnj.org/     76
# http://www.jhsph.edu/                 68
# http://www.academyhealth.org/         67
# http://www.gwu.edu/                   65
# http://www.mailman.columbia.edu/      65
# http://www.chcs.org/                  62
# http://www.nyam.org/                  61
# http://medschool.ucsf.edu/            58
# http://sph.berkeley.edu/              53
# Name: website, dtype: int64

# %%
#Addresses will need to be geocoded. It would be trivial to extract postcodes with a list of US states.
rwj['address'].value_counts()[:10]
# Out:
# Harvard University T. H. Chan School of Public Health\n677 Huntington Avenue\nBoston, MA 02115-6028\n617-432-1015                                                   134
# Rand Corporation\n1776 Main Street\nP.O. Box 2138\nSanta Monica, CA 90401-2138\n310-393-0411                                                                        107
# Mathematica Policy Research, Inc.\n600 Alexander Park\nP.O. Box 2393\nPrinceton, NJ 08543-2393\n609-799-3535                                                        105
# Urban Institute\n2100 M Street, N.W.\nWashington, DC 20037-1207\n202-833-7200                                                                                       103
# National Academies of Sciences, Engineering, and Medicine\n500 Fifth Street, N.W.\nWashington, DC 20001-2736\n202-334-2000                                           93
# University of Minnesota School of Public Health\nMayo Mail Code 197\n420 Delaware Street, S.E.\nMinneapolis, MN 55455-0381\n612-624-6669                             88
# University of Michigan School of Public Health\n1420 Washington Heights\nAnn Arbor, MI 48109-2013\n734-764-5425                                                      82
# Public Health Institute\n555 12th Street, 10th Floor\nOakland, CA 94607-4046\n510-285-5500                                                                           81
# University of California, Los Angeles, David Geffen School of Medicine\n10833 LeConte Avenue\nBox 951736\nLos Angeles, CA 90095-1736\n310-825-6373                   80
# University of Wisconsin-Madison School of Medicine and Public Health\nHealth Sciences Learning Center\n750 Highland Avenue\nMadison, WI 53705-2221\n608-263-4900     78
# Name: address, dtype: int64

# %%
#Should check how many of these are not in the US, and if they are not in the US, where are they

# %% [markdown]
# ### Top topics
#
# What are the top topics in the data? What are the top words, based on the 'abouts'? What
# are the funding trends for different areas?

# %%
def flatten_list(list):
    '''
    Flatten a list with nested elements
    '''
    
    flat = [x for el in list for x in el]
    return(flat)

# %%
#Here are the topics. These are interesting labels to consider when looking at health outcomes
topic_counts = pd.Series(flatten_list(rwj['topics'].dropna())).value_counts()

real_topics = topic_counts[topic_counts>5].index

# %%
#We would want to look at trends: Number of appearances of topics per year
#This list comprehension

#Flattens a list of topics for a year (i.e. gives the count of topics for that year) and puts in a dataframe
year_freq = pd.DataFrame({y:pd.Series(flatten_list(list(rwj.loc[rwj['year']==y,'topics'].dropna()))).value_counts() for y in 
                          range(2007,2018)}).fillna(0).loc[real_topics].T

#Calculate rolling means
year_freq_rolling = year_freq.rolling(window=3).mean()

#Plot
fig,ax = plt.subplots(figsize=(12,5))

year_freq_rolling.plot(ax=ax,linewidth=3,cmap='tab20',title='Number of projects per year (3-year Rolling averages)')

ax.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# It seems that system-level determinants of health (*social* and *built environment*) and *early childhood development* have become more important. *Childhood obesity* has lost importance

# %%
# Now I want to create similar graphs but for totals funded. How do we do this?

def filter_on_element(df,filter_variable,filter_value):
    '''
    This function takes a df where one variable filter_var is a list where every list is a nested element 
    and returns a boolean telling us if the list hasa filter value or not
    We need to run this in a df with no missing values.
    
    '''
    
    #Simple
    
    #We can't filter on missing values so we ignore them
    
    df_with_values = df.dropna(axis=0,subset=[filter_variable])
    
    #Subset the df with values on the filter variable
    filtered_df = df_with_values.loc[[filter_value in items for items in df_with_values[filter_variable]],:]

    #Return Boolean.
    return(filtered_df)

# %%
#This is a complicated list comprehension. Let's see how it works.
#For each year, it loops over the topics and creates a one-element named Series with the totals raised
#by projects with the topic. It concatenates it over the year, and over all years.

awarded_year_topic = pd.concat([pd.concat([pd.Series(
    filter_on_element(rwj.loc[rwj.year==y],'topics',topic).groupby('year')['awarded_$'].sum(),
    name=topic)for topic in real_topics],axis=1) for y in np.arange(2007,2018)])


#Calculate rolling means
year_awarded_rolling = awarded_year_topic.rolling(window=3).mean()

#Plot
fig,ax = plt.subplots(figsize=(12,5))

year_awarded_rolling.plot(ax=ax,linewidth=3,cmap='tab20',title='Awarded to project with topic (3-year Rolling averages)')

ax.legend(bbox_to_anchor=(1,1))

# %%
#Correlations between topics
#Focus on df that has topics
rwj_with_topics = rwj.dropna(axis=0,subset=['topics'])

#Create a topic boolean
topic_bool = pd.concat([pd.Series(
    [1 if top in x else 0 for x in rwj_with_topics['topics']],name=top) for top in real_topics],axis=1)

# %%
#Create a similarity metric and visualise
#We need to import the metrics
from sklearn.metrics.pairwise import pairwise_distances

#Similarities are the opposite of distances
topic_distances = 1- pairwise_distances(topic_bool.T,metric='jaccard')

np.fill_diagonal(topic_distances,np.nan)
# Out:
# /usr/local/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to bool by check_pairwise_arrays.
#   warnings.warn(msg, DataConversionWarning)

# %%
fig,ax = plt.subplots(figsize=(8,5))

im = ax.imshow(topic_distances,aspect='auto',cmap='seismic')
ax.set_xticks(np.arange(0,15))
ax.set_xticklabels(topic_bool.T.index,rotation=45,ha='right')

ax.set_yticks(np.arange(0,15))
ax.set_yticklabels(topic_bool.T.index)

fig.colorbar(im)

ax.set_title('Similarity between topics based on co-occurrence in projects')
# Out:
# Text(0.5,1,'Similarity between topics based on co-occurrence in projects')

# %% [markdown]
# Frequent topics are more similar. Hard to discern is this is an artifact of the way the projects are labelled or of their actual similarity

# %% [markdown]
# ### Top words
#
# And now we focus on words. This will be important because it will determine if we can use NLP on topic descriptions

# %%
#Remove the abouts
rwj_has_ab = rwj.dropna(axis=0,subset=['about'])

# %%
#Create a tokenised about
#Too many chained methods here?

#NB we are using 'threshold' to extract phrases from the corpus

rwj_has_ab['about_tokenised'] = CleanTokenize(rwj_has_ab['about']).clean().bigram(threshold=100).tokenised

rwj_has_ab['token_length'] = [len(x) for x in rwj_has_ab['about_tokenised']]
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#What are the top words
token_freqs = pd.Series(flatten_list(rwj_has_ab['about_tokenised']),name='freq').value_counts()

#The top words are not very informative
token_freqs[:20]
# Out:
# health         32146
# program        17248
# care           14273
# project        12445
# support        10354
# foundations     9446
# research        9289
# policy          8343
# grant           8330
# designed        8204
# new             7890
# community       7773
# public          7252
# national        6829
# services        6295
# nursing         5610
# provide         5524
# state           5507
# foundation      5343
# include         5325
# Name: freq, dtype: int64

# %%
print(token_freqs.describe())

print('\n')

print(np.sum(token_freqs>10))
# Out:
# count    33300.000000
# mean        37.043153
# std        324.738448
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          9.000000
# max      32146.000000
# Name: freq, dtype: float64
#
#
# 7624

# %% [markdown]
# There are 55732 tokens in the corpus. The top word is health (unsurprisingly!). The median word appears 2 times
# and there are 7600 tokens that appear more than 10 times. We might be able to use this in a topic modelling exercise or classification of projects into health areas.

# %%
plt.plot(rwj_has_ab.groupby('year')['token_length'].mean())

# %% [markdown]
# ## Exploratory topic modelling
#
# Here we perform an exploratory topic modelling of the RWJF data. We simply want to map the activities being undertaken.
#
# We use a script we have created with a standard LDA pipeline based on Gensim.
#
# We will then explore the results using pyLDA viz

# %%
print('running 1')

test_norm = LdaPipeline(rwj_has_ab['about_tokenised']).filter(3).process().fit_lda(
    num_topics=50,passes=20,iterations=130)

print('running 2')

test_tf = LdaPipeline(rwj_has_ab['about_tokenised']).filter(3).process().tfidf().fit_lda(
    num_topics=50,passes=20,iterations=130)
# Out:
# running 1
# running 2

# %%
test_norm.lda_topics
# Out:
# [(0,
#   '0.041*"model" + 0.016*"families" + 0.015*"whole" + 0.014*"county" + 0.014*"mexico" + 0.011*"readiness" + 0.011*"replication" + 0.011*"scale" + 0.011*"case" + 0.009*"staffing"'),
#  (1,
#   '0.075*"johnson" + 0.074*"robert_wood" + 0.055*"program" + 0.046*"foundation" + 0.044*"leadership" + 0.043*"rwjf" + 0.042*"research" + 0.038*"scholars" + 0.031*"grant" + 0.031*"support"'),
#  (2,
#   '0.075*"services" + 0.058*"community" + 0.039*"health" + 0.034*"project" + 0.028*"coalition" + 0.022*"conditions" + 0.020*"care" + 0.020*"develop" + 0.020*"foundations" + 0.019*"designed"'),
#  (3,
#   '0.082*"evaluation" + 0.024*"innovations" + 0.024*"innovation" + 0.022*"online" + 0.018*"open" + 0.018*"sustainability" + 0.017*"plan" + 0.015*"implementation" + 0.015*"development" + 0.012*"organizational"'),
#  (4,
#   '0.072*"state" + 0.048*"states" + 0.046*"coverage" + 0.033*"health" + 0.031*"medicaid" + 0.029*"insurance" + 0.025*"care" + 0.018*"enrollment" + 0.015*"federal" + 0.012*"access"'),
#  (5,
#   '0.056*"program" + 0.029*"participants" + 0.016*"foundations" + 0.015*"least" + 0.014*"benefit" + 0.014*"newark" + 0.013*"four" + 0.012*"user" + 0.012*"grant" + 0.011*"provided"'),
#  (6,
#   '0.040*"program" + 0.030*"designed" + 0.030*"health" + 0.029*"providing" + 0.028*"chronic" + 0.027*"volunteer_caregiving" + 0.027*"expand_continued" + 0.026*"people_ages" + 0.025*"model" + 0.025*"volunteer_caregivers"'),
#  (7,
#   '0.059*"conference" + 0.033*"meeting" + 0.030*"national" + 0.020*"deliverables" + 0.020*"annual" + 0.018*"grant" + 0.016*"include" + 0.014*"forum" + 0.011*"supports" + 0.011*"participants"'),
#  (8,
#   '0.049*"tobacco" + 0.038*"policy" + 0.032*"campaign" + 0.022*"advocacy" + 0.016*"coalitions" + 0.016*"prevention" + 0.015*"use" + 0.015*"coalition" + 0.015*"national" + 0.014*"policies"')]

# %% [markdown]
# The topics are a bit hit and miss. We seem to be picking up health issues rather than health innovations. Perhaps we need more text?

# %% [markdown]
# #### Explore the data using PyLDAvis?
#
# Unfortunately pyLDAvis doesn't seem to play nice with JupyterLabs yet. We have to display the visualisations in a different window

# %%
#We will display it separately
import pyLDAvis.gensim
#pyLDAvis.enable_notebook()

#ldavis_norm = pyLDAvis.gensim.prepare(test_norm.lda_model,test_norm.corpus,test_norm.dictionary)
#pyLDAvis.save_html(ldavis_norm,fig_path+'/{date}_test_viz.html'.format(date=today_str))

#ldavis_tfidf = pyLDAvis.gensim.prepare(test_tf.lda_model,test_tf.corpus,test_tf.dictionary)
#pyLDAvis.save_html(ldavis_tfidf,fig_path+'/{date}_test_viz_tfidf.html'.format(date=today_str))

# %% [markdown]
# ### Word embedding and document embedding analysis
#
# Another option is to cluster the documents using Doc2vec, which will represent each project in a vector space based on the semantic similarity between its words. We can then cluster these documents and extract their top words in order to identify what they are about.
#
# Activities:
#
# * Train the doc2vec model on the data.
# * Cluster the docs
# * Benchmark the clusters
# * Label the docs

# %%
from gensim.models.doc2vec import TaggedDocument
from gensim import models

#This creates a list where every element is a tag (doc title) and a list of words.
#We train the model on that
sents = [TaggedDocument(tags=[x],words=y) for x,y in zip(rwj_has_ab['title'],rwj_has_ab['about_tokenised'])]

#Train model (NB I havent tuned the d2v)
d2v = models.Doc2Vec(sents)

#Create document vector matrix
document_vectors = np.array([d2v.docvecs[t] for t in rwj_has_ab['title']])

# %% [markdown]
# ### Clustering analysis
#
# We want to cluster the documents.
#
# We will build a pipeline to do this. How is it going to work?
#
# * Initialise the class with the records (nrows = records, columns=features for clustering)
# * Input the parameters for grid-search (eg number of clusters, other variables)
# * Estimate silouhette scores to compare model performance across algorithms and parameters
# * Return models
# * Select models
# * Re-run models for robust allocation of observations to clusters via community detection
# * Obtain and name clusters (we will create a function that does this based on the salient terms in the cluster group)
# * We can then explore the occurrence of technology areas across these clusters.
# * There is no reason why we couldn't cluster the documents using other vector representations (eg topics via
# LDA etc.)

# %%
#Imports

from itertools import product

from sklearn.cluster import KMeans, DBSCAN, AffinityPropagation, MeanShift, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, silhouette_samples

from yellowbrick.cluster.elbow import KElbowVisualizer
from yellowbrick.cluster.silhouette import SilhouetteVisualizer
from yellowbrick.text import TSNEVisualizer

# %%
class ClusterDecider():
    '''
    This class is initialised with a df or array where: 
    
        -Rows are the elements we want to cluster
        -Columns are the features we want to use for the clustering (might have done dimensionality reduction on them)
    
    Methods:
    
        
        -grid_search method taking a list of clustering algorithms and parameters to do grid search over
        [need to remember to import clustering algorithms]. This involves creating a cartesian product
        of algorithms, fitting the models and predicting the labels.
    
        TODO -evaluation method estimates metrics of clustering performance based on silouhette score. If
        we use a word_similarity metric then we will run a custom-made algorithm that estimates the 
        average distances between salient words in each cluster compared to those in other clusters,
        
        -Return a dict with all the models we fit, their parameters and scores.
        
        We will evaluate these manually, and through Yellowbrick.
    
    '''
    
    def __init__(self,records):
        '''
        Initialise an instance of the object.
        
        '''
        
        self.records = records
    
    def grid_search(self,cluster_list):
        '''
        Loops through the cluster list and creates a grid search based on the parameters
        The parameters are in the second element of each cluster, as a tuple 
        where the first value is the name of the parameter and the rest are 
        
        
        '''
        
        #Read the records
        records = self.records
        
        #Store clustering results in a dict
        self.clustering = {}
        
        #We loop over each cluster and create combinations of parameters
        for clust in cluster_list:
            cl_algo = clust[0]
            
            #We get the cluster name in a hacky way via regex
            cluster_name = re.sub('_','',str(clust[0]).split('.')[2])
            
            print('running '+cluster_name)
            
            #This extracts the dictionary of parameters from the clust list
            #and creates a cartesian product (all possible combinations of values)
            par_comb = list(product(*clust[1].values()))
            
            #And this turns the cartesian product into a list of dicts with named parameters
            par_list = [{par:val for par,val in zip(clust[1].keys(),par_vals)} for par_vals in par_comb]
            
            #Now we can loop over this list to to run each cluster:
            
            for parameters in par_list:
                #Initialise the cluster and set parameters
                cl = cl_algo().set_params(**parameters)
                
                #Fit the cluster
                cl.fit(records)
                
                #We also want to estimate the silouhette scores etc.
                sil_score = silhouette_score(records,cl.labels_)
                
                #Store results
                self.clustering['_'.join([cluster_name]+[k+':'+str(v) for k,v in parameters.items()])]=[
                    cl,
                    cl.labels_,
                    sil_score]
            
                #We also want to estimate the silouhette scores etc.   
                
        return(self)
                
    def cluster_scores(self):
        '''
        Takes the scores from the clustering algorithms and plots them
        
        '''
        
        #Extract scores
        scores = pd.DataFrame([{'name':k,'score':v[-1]} for k,v in self.clustering.items()]).sort_values('score')   
        
        fig,ax = plt.subplots()

        scores['score'].plot.bar(ax=ax,color='blue')

        ax.set_xticklabels(scores['name'])
        ax.set_title('Silouhette scores')
        
        return(ax)

# %%
def visual_validation(cluster_labels,sort_results=True,print_n='all',subset=False):
    '''
    This function takes a list of cluster labels and returns some information about their content:
    Number of observations, titles, distinctive words...
    
    We can ask it to sort the data (start with the biggest clusters) and limit the numbers
    that are printed (if we have lots). We can also ask it to print a subset of the clusters
    
    '''
    
    rwj_clust = pd.concat([rwj_has_ab[['title','about_tokenised']]])
    rwj_clust['cluster'] = cluster_labels

    if sort_results == True:
    #If we want to present the results labelled
        cluster_labels = pd.Series(cluster_labels).value_counts().index
    
    else:
        cluster_labels = sorted(list(set(cluster_labels)))
    
    
    if subset!=False:
        cluster_labels = [x for x in cluster_labels if x in subset]
    
    if print_n!='all':
        '''
        Select how many to print
        
        '''
        
        cluster_labels = cluster_labels[:print_n]
        
    
    for x in cluster_labels:


        rel = rwj_clust.loc[rwj_clust['cluster']==x]

        print(x)
        print(len(rel))

        print(rel.head())

        print('\n')

        el_freq = pd.Series(flatten_list(rel['about_tokenised']),name=x).value_counts()[:50]

        norm_freq = pd.concat([el_freq,token_freqs],axis=1)
        norm_freq['norm'] = norm_freq[x]/norm_freq['freq']

        print(norm_freq.sort_values('norm',ascending=False)[:10])    

        print('\n')

# %%
cd = ClusterDecider(document_vectors)

clusts= [
    #[SpectralClustering,{'n_clusters':np.arange(10,20,2)}],
    [KMeans,{'n_clusters':np.arange(15,40,2)}],
    #[DBSCAN,{}],
    #[MeanShift,{'cluster_all':[True,False]}],
    #[AffinityPropagation,{}]
         ]

cd.grid_search(cluster_list=clusts)

cd.cluster_scores()
# Out:
# running kmeans

# %%
sel_labs = cd.clustering['kmeans_n_clusters:15'][1]

visual_validation(sel_labs,print_n=10)
# Out:
# 0
# 10154
#                                                  title  \
# 114  Program to Promote Long-Term Care Insurance fo...
# 116  Medicaid coverage of smoking cessation treatments
# 119  Building a comprehensive cross-sector initiati...
# 123  Evaluation of the Partnerships for Training Pr...
# 125  Bridge grant for RWJF state-community family s...
#
#                                        about_tokenised  cluster
# 114  [foundations, program, promote, long-term, car...        0
# 116  [foundations, program, smoke-free, families, i...        0
# 119  [grant, supports, implementation, comprehensiv...        0
# 123  [foundations, program, partnerships, training,...        0
# 125  [foundations, family, support, services, progr...        0
#
#
#                    0  freq      norm
# deliverables  2839.0  2904  0.977617
# study         2857.0  2933  0.974088
# data          3807.0  3989  0.954375
# evaluation    2217.0  2406  0.921446
# identify      2104.0  2284  0.921191
# foundation    4766.0  5343  0.892008
# among         2187.0  2473  0.884351
# policy        7351.0  8343  0.881098
# funding       2549.0  2900  0.878966
# information   2418.0  2761  0.875770
#
#
# 10
# 838
#                                                  title  \
# 128          Generalist Physician Initiative (Phase 2)
# 142  Technical assistance and direction for the Cas...
# 147  Technical assistance and direction for Reducin...
# 155  Technical assistance and direction for RWJF's ...
# 165  Technical assistance and direction for RWJF's ...
#
#                                        about_tokenised  cluster
# 128  [foundations, generalist_physician, initiative...       10
# 142  [foundations, cash_counseling, program, design...       10
# 147  [foundations, program, reducing_underage, drin...       10
# 155  [foundations, home, care, research, initiative...       10
# 165  [foundations, program, urban, health, initiati...       10
#
#
#                           10   freq      norm
# direction              246.0    667  0.368816
# partnerships           211.0    871  0.242250
# technical_assistance   540.0   2401  0.224906
# office                 211.0    961  0.219563
# grantees               226.0   1202  0.188020
# sites                  187.0   1180  0.158475
# systems                274.0   2003  0.136795
# provides               278.0   2038  0.136408
# local                  540.0   4261  0.126731
# program               1846.0  17248  0.107027
#
#
# 2
# 483
#                 title                                    about_tokenised  \
# 3699  Faith in Action  [foundations, program, faith_action®, designed...
# 3700  Faith in Action  [foundations, faith_action®, program, designed...
# 3701  Faith in Action  [foundations, program, faith_action®, designed...
# 3702  Faith in Action  [foundations, program, faith_action®, designed...
# 3703  Faith in Action  [foundations, program, faith_action®, designed...
#
#       cluster
# 3699        2
# 3700        2
# 3701        2
# 3702        2
# 3703        2
#
#
#                            2  freq      norm
# friendly_visiting      117.0   117  1.000000
# telephone_reassurance  101.0   101  1.000000
# faith_action®          483.0   495  0.975758
# expand_continued       483.0   500  0.966000
# volunteer_caregiving   488.0   508  0.960630
# respite                157.0   168  0.934524
# mission                407.0   719  0.566064
# conditionsthis         329.0   590  0.557627
# faith                   84.0   152  0.552632
# volunteer_caregivers   491.0   957  0.513062
#
#
# 3
# 441
#                                                  title  \
# 282  Faith in Action: Replication of the Interfaith...
# 305  Faith in Action: Replication of the Interfaith...
# 338  Faith in Action: Replication of the Interfaith...
# 341  Faith in Action: Replication of the Interfaith...
# 342  Faith in Action: Replication of the Interfaith...
#
#                                        about_tokenised  cluster
# 282  [foundations, faith_action, replication_interf...        3
# 305  [foundations, faith_action, replication_interf...        3
# 338  [foundations, faith_action, replication_interf...        3
# 341  [foundations, faith_action, replication_interf...        3
# 342  [foundations, faith_action, replication_interf...        3
#
#
#                               3  freq      norm
# faiths_chronic            436.0   437  0.997712
# organizations_match       436.0   437  0.997712
# chores_well               436.0   437  0.997712
# referrals_relevant        436.0   437  0.997712
# conditions_kinds          436.0   437  0.997712
# people_wide               436.0   438  0.995434
# organize_train            436.0   439  0.993166
# religious_congregations   436.0   439  0.993166
# companionship_assistance  436.0   440  0.990909
# individual_needs          436.0   446  0.977578
#
#
# 1
# 307
#                                                    title  \
# 10414  Robert Wood Johnson Foundation New Careers in ...
# 10416  Robert Wood Johnson Foundation New Careers in ...
# 10417  Robert Wood Johnson Foundation New Careers in ...
# 10418  Robert Wood Johnson Foundation New Careers in ...
# 10419  Robert Wood Johnson Foundation New Careers in ...
#
#                                          about_tokenised  cluster
# 10414  [foundations, new, careers, nursing, scholarsh...        1
# 10416  [foundations, new, careers, nursing, scholarsh...        1
# 10417  [foundations, new, careers, nursing, scholarsh...        1
# 10418  [foundations, new, careers, nursing, scholarsh...        1
# 10419  [foundations, new, careers, nursing, scholarsh...        1
#
#
#                           1  freq      norm
# funding_competitive   306.0   307  0.996743
# recipients_academic   306.0   307  0.996743
# progress_scholarship  306.0   307  0.996743
# tuition_academic      305.0   306  0.996732
# students_accepted     222.0   223  0.995516
# fees_subsidy          221.0   222  0.995495
# used_supplant         219.0   220  0.995455
# resources_loan        219.0   220  0.995455
# year_result           303.0   305  0.993443
# masters_degree        275.0   277  0.992780
#
#
# 5
# 211
#                                                  title  \
# 221  Free to Grow: Head Start Partnerships to Promo...
# 247          SmokeLess States Program - Implementation
# 427  Reducing Underage Drinking Through Community a...
# 428  Reducing Underage Drinking Through Community a...
# 431  Reducing Underage Drinking Through Community a...
#
#                                        about_tokenised  cluster
# 221  [foundations, program, free_grow, head_start, ...        5
# 247  [foundations, smokeless_states, national, toba...        5
# 427  [foundations, program, reducing_underage, drin...        5
# 428  [foundations, program, reducing_underage, drin...        5
# 431  [foundations, program, reducing_underage, drin...        5
#
#
#                    5  freq      norm
# head_start      69.0   121  0.570248
# statewide      108.0   632  0.170886
# coalitions      98.0   598  0.163880
# youth          183.0  1450  0.126207
# safety          76.0   608  0.125000
# reduce         157.0  1320  0.118939
# tobacco        229.0  2092  0.109465
# prevention     171.0  1745  0.097994
# comprehensive   98.0  1019  0.096173
# coalition      122.0  1269  0.096139
#
#
# 13
# 134
#                                                   title  \
# 236   Technical assistance and direction for the Rob...
# 868   Robert Wood Johnson Foundation Clinical Schola...
# 1117  Technical assistance and direction for the Rob...
# 1197  Technical assistance and direction for RWJF's ...
# 1724  Robert Wood Johnson Foundation Clinical Schola...
#
#
#                             4  freq      norm
# nine_joint               60.0    60  1.000000
# application_acceptance   63.0    63  1.000000
# set_predetermined        63.0    64  0.984375
# basic_sciences           63.0    66  0.954545
# organic_chemistry        63.0    66  0.954545
# physics_biology          63.0    66  0.954545
# programmatic_principles  63.0    67  0.940299
# structured_around        63.0    67  0.940299
# core_operational         63.0    68  0.926471
# areas_economically       76.0    95  0.800000

# %% [markdown]
# ### Additional processing
#
# Currently, the clustering algorithm is picking up programmes with repeated titles.
#
# We want to remove those. How do we do it?
#
# Idea: cluster documents on their titles using doc2vec and then identify which clusters are
# most homogeneous (eg average levehnstein distances between all components is lower.
# We then allocate all documents in 'programme clusters' in there, and redo the clustering

# %%
#We tokenise titles
titles_tokenised = CleanTokenize(rwj_has_ab['title']).clean().bigram(threshold=100).tokenised

#We train the model on that
sents_dedupe = [TaggedDocument(tags=[x],words=y) for x,y in zip(rwj_has_ab['title'],titles_tokenised)]

#Train model (NB I havent tuned the d2v)
d2v_title = models.Doc2Vec(sents_dedupe)

#Create document vector matrix
document_vectors_titles = np.array([d2v_title.docvecs[t] for t in rwj_has_ab['title']])

# %%
#Run the clustering as before
cd_titles = ClusterDecider(document_vectors_titles)

clusts= [
    #[SpectralClustering,{'n_clusters':np.arange(10,20,2)}],
    [KMeans,{'n_clusters':np.arange(30,80,5)}],
    #[DBSCAN,{}],
    #[MeanShift,{'cluster_all':[True,False]}],
    #[AffinityPropagation,{}]
         ]

cd_titles.grid_search(cluster_list=clusts)

cd_titles.cluster_scores()
# Out:
# running kmeans

# %% [markdown]
# We want to allocate 'repeated' clusters (with the same title) to the same cluster and normalise.
#
# Otherwise any cluster analysis or topic modelling we do is going to keep picking up those repeated clusters
#
# We identify what these clusters are with the mean/variance distance between observations and the cluster centroid (clusters with large/variant distances will be more dispersed than those with small/invariant distances, and less likely to contain repeated programmes

# %%
from sklearn.metrics import pairwise

# %%
test_cluster = cd_titles.clustering['kmeans_n_clusters:60'][0]

#For each cluster, we will calculate distance mean and variance between all observations and the centre.

container = []

for clust in list(set(test_cluster.labels_)):
    #print(clust)
    # Find the document vectors in the cluster
    
    #Subset the document vectors to get those in the cluster
    vectors = np.array(document_vectors_titles)[[val==clust for val in test_cluster.labels_],:]
    
    size = len(vectors)
    
    #print(vectors.shape)
    
    #Extract the centroid
    centroid = test_cluster.cluster_centers_[x]
    
    #print(centroid)
    
    #Calculate all distances
    distances = pairwise.cosine_distances(vectors,centroid.reshape(1,-1))
    
    #print(distances.shape)
    
    #Calculate distance mean and variance
    median = np.median(distances)
    
    variance = np.round(np.var(distances),3)
    
    container.append([clust,size,median,variance])

# %%
zero_var = [x[0] for x in container if x[3]==0]
non_zero_var = [x[0] for x in container if x[0] not in zero_var]

#non_zero_var = [x[0] for x in container if x[0] not in zero_var]

# %%
visual_validation(cd_titles.clustering['kmeans_n_clusters:60'][1],sort_results=False,
                  subset=zero_var)
# Out:
# 1
# 483
#                 title                                    about_tokenised  \
# 3699  Faith in Action  [foundations, program, faith_action®, designed...
# 3700  Faith in Action  [foundations, faith_action®, program, designed...
# 3701  Faith in Action  [foundations, program, faith_action®, designed...
# 3702  Faith in Action  [foundations, program, faith_action®, designed...
# 3703  Faith in Action  [foundations, program, faith_action®, designed...
#
#       cluster
# 3699        1
# 3700        1
# 3701        1
# 3702        1
# 3703        1
#
#
#                            1  freq      norm
# friendly_visiting      117.0   117  1.000000
# telephone_reassurance  101.0   101  1.000000
# faith_action®          483.0   495  0.975758
# expand_continued       483.0   500  0.966000
# volunteer_caregiving   488.0   508  0.960630
# respite                157.0   168  0.934524
# mission                407.0   719  0.566064
# conditionsthis         329.0   590  0.557627
# faith                   84.0   152  0.552632
# volunteer_caregivers   491.0   957  0.513062
#
#
# 2
# 307
#                                                    title  \
# 10414  Robert Wood Johnson Foundation New Careers in ...
# 10416  Robert Wood Johnson Foundation New Careers in ...
# 10417  Robert Wood Johnson Foundation New Careers in ...
# 10418  Robert Wood Johnson Foundation New Careers in ...
# 10419  Robert Wood Johnson Foundation New Careers in ...
#
#                                          about_tokenised  cluster
# 10414  [foundations, new, careers, nursing, scholarsh...        2
# 10416  [foundations, new, careers, nursing, scholarsh...        2
# 10417  [foundations, new, careers, nursing, scholarsh...        2
# 10418  [foundations, new, careers, nursing, scholarsh...        2
# 10419  [foundations, new, careers, nursing, scholarsh...        2
#
#
#                           2  freq      norm
# funding_competitive   306.0   307  0.996743
# recipients_academic   306.0   307  0.996743
# progress_scholarship  306.0   307  0.996743
# tuition_academic      305.0   306  0.996732
# students_accepted     222.0   223  0.995516
# fees_subsidy          221.0   222  0.995495
# used_supplant         219.0   220  0.995455
# resources_loan        219.0   220  0.995455
# year_result           303.0   305  0.993443
# masters_degree        275.0   277  0.992780
#
#
# 3
# 441
#                                                  title  \
# 282  Faith in Action: Replication of the Interfaith...
# 305  Faith in Action: Replication of the Interfaith...
# 338  Faith in Action: Replication of the Interfaith...
# 341  Faith in Action: Replication of the Interfaith...
# 342  Faith in Action: Replication of the Interfaith...
#
#                                        about_tokenised  cluster
# 282  [foundations, faith_action, replication_interf...        3
# 305  [foundations, faith_action, replication_interf...        3
# 338  [foundations, faith_action, replication_interf...        3
# 341  [foundations, faith_action, replication_interf...        3
# 342  [foundations, faith_action, replication_interf...        3
#
#
#                               3  freq      norm
# faiths_chronic            436.0   437  0.997712
# organizations_match       436.0   437  0.997712
# chores_well               436.0   437  0.997712
# referrals_relevant        436.0   437  0.997712
# conditions_kinds          436.0   437  0.997712
# people_wide               436.0   438  0.995434
# organize_train            436.0   439  0.993166
# religious_congregations   436.0   439  0.993166
# companionship_assistance  436.0   440  0.990909
# individual_needs          436.0   446  0.977578
#
#
# 4
# 90
#                                                    title  \
# 9969   Consumer Voices for Coverage: Strengthening St...
# 9970   Consumer Voices for Coverage: Strengthening St...
# 9973   Consumer Voices for Coverage: Strengthening St...
# 9976   Consumer Voices for Coverage: Strengthening St...
# 10604  Consumer Voices for Coverage: Strengthening St...
#
#                                          about_tokenised  cluster
# 9969   [foundations, program, consumer_voices, covera...        4
# coverage_programsworking  30.0    36  0.833333
# low-income_uninsured      32.0    98  0.326531
# private-sector            30.0   109  0.275229
# covering_kids             33.0   131  0.251908
# enroll                    33.0   194  0.170103
# eligible                  65.0   501  0.129741
# traditional               30.0   264  0.113636
# coordinate                31.0   347  0.089337
# benefit                   30.0   457  0.065646
#
#
# 14
# 31
#                                                   title  \
# 221   Free to Grow: Head Start Partnerships to Promo...
# 4182  Free to Grow: Head Start Partnerships to Promo...
# 4183  Free to Grow: Head Start Partnerships to Promo...
# 4184  Free to Grow: Head Start Partnerships to Promo...
# 4186  Free to Grow: Head Start Partnerships to Promo...
#
#                                         about_tokenised  cluster
# 221   [foundations, program, free_grow, head_start, ...       14
# 4182  [foundations, program, free_grow, head_start, ...       14
# 4183  [foundations, program, free_grow, head_start, ...       14
# 4184  [foundations, program, free_grow, head_start, ...       14
# 4186  [foundations, program, free_grow, head_start, ...       14
#
#
#                           14  freq      norm
# selected_head           31.0    40  0.775000
# young_childs            31.0    41  0.756098
# agencies_adapt          31.0    41  0.756098
# family_communitythe      9.0    12  0.750000
# promote_substance-free  31.0    42  0.738095
# free_grow               53.0    80  0.662500
# head_start              69.0   121  0.570248
# start                   36.0   115  0.313043
# aim                     32.0   264  0.121212
# substance_abuse         66.0  1204  0.054817
#
#
# 16
# 19
#                                                   title  \
# 3796  Technical assistance and direction for RWJF's ...
# 3829  Technical assistance and direction for RWJF's ...
# 3945  Technical assistance and direction for RWJF's ...
# 5196  Technical assistance and direction for RWJF's ...
# 5915  Technical assistance and direction for RWJF's ...
#
#                                         about_tokenised  cluster
# 3796  [foundations, program, community, partnerships...       16
# 3829  [foundations, program, community, partnerships...       16
# 3945  [foundations, program, community, partnerships...       16
# 5196  [foundations, program, community, partnerships...       16
# 5915  [foundations, program, community, partnerships...       16
#
#
#                                16  freq      norm
# times_delays                  9.0     9  1.000000
# reductions_wait               9.0     9  1.000000
# system_wholethis              9.0    11  0.818182
# urgent_matters               18.0    27  0.666667
# functions_workings            9.0    15  0.600000
# output                        9.0    18  0.500000
# um                            9.0    23  0.391304
# older_adultsthis             10.0    35  0.285714
# public-private_partnerships  10.0    65  0.153846
# chosen                        9.0    60  0.150000
#
#
# 17
# 31
#                                                  title  \
# 535  Self-Determination for Persons with Developmen...
# 536  Self-Determination for Persons with Developmen...
# 537  Self-Determination for Persons with Developmen...
# 538  Self-Determination for Persons with Developmen...
# 539  Self-Determination for Persons with Developmen...
#
#                                        about_tokenised  cluster
# 535  [foundations, program, self-determination_pers...       17
# 536  [foundations, program, self-determination_pers...       17
# 537  [foundations, program, self-determination_pers...       17
# 538  [foundations, program, self-determination_pers...       17
# 539  [foundations, program, self-determination_pers...       17
#
#
#                               17  freq      norm
# persons_rather              16.0    17  0.941176
# recognize_abilities         16.0    17  0.941176
# enact_reforms               16.0    18  0.888889
# monitoring_follow-up        28.0    35  0.800000
# self-determination_persons  30.0    39  0.769231
# simultaneously_allowing     16.0    24  0.666667
# kids_count                  28.0    46  0.608696
# developmental_disabilities  31.0    53  0.584906
# receivethis                 16.0    37  0.432432
# registry                    28.0    83  0.337349
#
#
# 18
# 32
#                                                   title  \
# 4811  Robert Wood Johnson Foundation Health & Societ...
# 4812  Robert Wood Johnson Foundation Health & Societ...
# 5293  Robert Wood Johnson Foundation Health & Societ...
# 5297  Robert Wood Johnson Foundation Health & Societ...
# 5300  Robert Wood Johnson Foundation Health & Societ...
#
#                                         about_tokenised  cluster
# 4811  [robert_wood, johnson, foundation, health, soc...       18
# 4812  [robert_wood, johnson, foundation, health, soc...       18
# 5293  [foundations, robert_wood, johnson, health, so...       18
# 5297  [foundations, robert_wood, johnson, health, so...       18
# 5300  [foundations, robert_wood, johnson, health, so...       18
#
#
#                             18  freq      norm
# hss                       21.0    22  0.954545
# upon_integration          35.0    45  0.777778
# among_biological          35.0    46  0.760870
# investigate_connections   35.0    46  0.760870
# determinantsthis          18.0    27  0.666667
# social_determinants       36.0   167  0.215569
# society                   61.0   321  0.190031
# disciplines               22.0   116  0.189655
# two-year                  18.0   128  0.140625
# scholars                 188.0  1569  0.119822
#
#
# 19
# 24
#                                                   title  \
# 3844  SmokeLess States: National Tobacco Policy Init...
# 3846  SmokeLess States: National Tobacco Policy Init...
# 3847  SmokeLess States: National Tobacco Policy Init...
# 3848  SmokeLess States: National Tobacco Policy Init...
# 3849  SmokeLess States: National Tobacco Policy Init...
#
#                                         about_tokenised  cluster
# 3844  [foundations, smokeless_states, national, toba...       19
# 3846  [foundations, smokeless_states, national, toba...       19
# 3847  [foundations, smokeless_states, national, toba...       19
# 3848  [foundations, smokeless_states, national, toba...       19
# 3849  [foundations, smokeless_states, national, toba...       19
#
#
#                     19  freq      norm
# excise_tax         9.0    25  0.360000
# preemption         8.0    24  0.333333
# smokeless_states  26.0   116  0.224138
# initiativesthis    9.0    50  0.180000
# initiativesthe    12.0    93  0.129032
# clean_indoor       8.0    96  0.083333
# smoke              8.0   103  0.077670
# statewide         42.0   632  0.066456
# air                8.0   151  0.052980
# tobacco           89.0  2092  0.042543
#
#
# 21
# 24
#                                                   title  \
# 1098  Injury Free Coalition for Kids: Dissemination ...
# 4648  Injury Free Coalition for Kids: Dissemination ...
# 4649  Injury Free Coalition for Kids: Dissemination ...
# 4653  Injury Free Coalition for Kids: Dissemination ...
# 4660  Injury Free Coalition for Kids: Dissemination ...
#
#                                         about_tokenised  cluster
# 1098  [foundations, program, injury_free, coalition,...       21
# 4648  [foundations, program, injury_free, coalition,...       21
# 4649  [foundations, program, injury_free, coalition,...       21
# 4653  [foundations, program, injury_free, coalition,...       21
# 4660  [foundations, program, injury_free, coalition,...       21
#
#
#                                   21  freq      norm
# helmet                           8.0     9  0.888889
# prevent_injuries                24.0    32  0.750000
# hospital-based_research-driven  24.0    32  0.750000
# stakeholdersthis                13.0    20  0.650000
# injury_free                     24.0    45  0.533333
# seat                             6.0    12  0.500000
# injury                          57.0   173  0.329480
# bicycle                         10.0    34  0.294118
# car                              5.0    17  0.294118
# injuries                        10.0    51  0.196078
#
#
# 24
# 16
#                                                   title  \
# 275   Technical assistance and direction for the Rob...
# 1203  Technical assistance and direction for the Rob...
# 2038  Technical assistance and direction for the Rob...
# 2737  Technical assistance and direction for the Rob...
# 3489  Technical assistance and direction for the Rob...
#
#                                         about_tokenised  cluster
# 275   [foundations, local, initiative, funding, part...       24
# 1203  [foundations, local, initiative, funding, part...       24
# 2038  [foundations, local, initiative, funding, part...       24
# 2737  [foundations, local, initiative, funding, part...       24
# 3489  [foundations, local, initiative, funding, part...       24
#
#
#                               24  freq      norm
# seitz                        4.0     5  0.800000
# pauline                      4.0     5  0.800000
# populationsthis             14.0    73  0.191781
# corporate                   11.0   132  0.083333
# matching_grants             16.0   246  0.065041
# underserved_vulnerable      15.0   233  0.064378
# establish_partnerships      16.0   250  0.064000
# innovative_community-based  16.0   269  0.059480
# directed                     4.0    91  0.043956
# grantmakers                 12.0   314  0.038217
#
#
# 25
# 20
#                                                   title  \
# 1315  Urban Health Initiative: Working to Ensure the...
# 1316  Urban Health Initiative: Working to Ensure the...
# 1317  Urban Health Initiative: Working to Ensure the...
# 1319  Urban Health Initiative: Working to Ensure the...
# 1322  Urban Health Initiative: Working to Ensure the...
#
#                                         about_tokenised  cluster
# 1315  [foundations, program, urban, health, initiati...       25
# 1316  [foundations, program, urban, health, initiati...       25
# 1317  [foundations, program, urban, health, initiati...       25
# 1319  [foundations, program, urban, health, initiati...       25
# 1322  [foundations, program, urban, health, initiati...       25
#
#
#                 25  freq      norm
# oakland        8.0    32  0.250000
# sound          8.0    85  0.094118
# after-school   8.0    93  0.086022
# safety        50.0   608  0.082237
# ten           14.0   194  0.072165
# safe          15.0   214  0.070093
# closely       14.0   227  0.061674
# cities        16.0   353  0.045326
# urban         27.0   673  0.040119
# violence      16.0   437  0.036613
#
#
# 29
# 23
#                                                   title  \
# 6446  Paths to Recovery: Changing the Process of Car...
# 6447  Paths to Recovery: Changing the Process of Car...
# 6450  Paths to Recovery: Changing the Process of Car...
# 6456  Paths to Recovery: Changing the Process of Car...
# 6457  Paths to Recovery: Changing the Process of Car...
#
#                                         about_tokenised  cluster
# 6446  [foundations, initiative, paths_recovery, chan...       29
# 6447  [foundations, initiative, paths_recovery, chan...       29
# 6450  [foundations, initiative, paths_recovery, chan...       29
# 6456  [foundations, initiative, paths_recovery, chan...       29
# 6457  [foundations, initiative, paths_recovery, chan...       29
#
#
#                         29  freq      norm
# ability_successfully  23.0    30  0.766667
# techniques_toward     23.0    30  0.766667
# paths_recovery        24.0    36  0.666667
# programsthe           16.0    32  0.500000
# retention             45.0   197  0.228426
# expects                9.0    66  0.136364
# addiction             49.0   372  0.131720
# changing              23.0   204  0.112745
# clients               28.0   249  0.112450
# intake                 9.0    87  0.103448
#
#
# 31
# 14
#                                                   title  \
# 2502  Colleagues in Caring: Regional Collaboratives ...
# 2503  Colleagues in Caring: Regional Collaboratives ...
# 2504  Colleagues in Caring: Regional Collaboratives ...
# 2505  Colleagues in Caring: Regional Collaboratives ...
# 2506  Colleagues in Caring: Regional Collaboratives ...
#
#                                         about_tokenised  cluster
# 2502  [foundations, program, colleagues_caring, regi...       31
# 2503  [foundations, program, colleagues_caring, coll...       31
# 2504  [foundations, program, colleagues_caring, coll...       31
# 2505  [foundations, program, colleagues_caring, coll...       31
# 2506  [foundations, program, colleagues_caring, coll...       31
#
#
#                          31  freq      norm
# mechanism_monitoring   13.0    18  0.722222
# assure_presence        13.0    18  0.722222
# create_authoritative   13.0    18  0.722222
# demand_supply          13.0    20  0.650000
# career_ladder          13.0    20  0.650000
# within_regionsthis     13.0    26  0.500000
# forecasting            13.0    28  0.464286
# institutions_initiate  14.0    31  0.451613
# concerted              14.0    38  0.368421
# force                  37.0   106  0.349057
#
#
# 32
# 14
#                                                   title  \
# 5561  Pipeline, Profession and Practice: Community-B...
# 5562  Pipeline, Profession and Practice: Community-B...
# 5566  Pipeline, Profession and Practice: Community-B...
# 5567  Pipeline, Profession and Practice: Community-B...
# 5568  Pipeline, Profession and Practice: Community-B...
#
#                                         about_tokenised  cluster
# 5561  [foundations, program, pipeline_profession, pr...       32
# 5562  [foundations, program, pipeline_profession, pr...       32
# 5566  [foundations, program, pipeline_profession, pr...       32
# 5567  [foundations, program, pipeline_profession, pr...       32
# 5568  [foundations, program, pipeline_profession, pr...       32
#
#
#                        32  freq      norm
# rotations             5.0     7  0.714286
# pipeline_profession  14.0    35  0.400000
# off-site              6.0    19  0.315789
# dentistry             9.0    31  0.290323
# weeks                 6.0    39  0.153846
# dental               68.0   633  0.107425
# populationsthe        5.0    59  0.084746
# populationsthis       5.0    73  0.068493
# underserved          18.0   295  0.061017
# native_american       6.0   100  0.060000
#
#
# 33
# 13
#                                                   title  \
# 2790  Technical assistance and direction for RWJF's ...
# 2922  Technical assistance and direction for RWJF's ...
# 3088  Technical assistance and direction for RWJF's ...
# 3110  Technical assistance and direction for RWJF's ...
# 3111  Technical assistance and direction for RWJF's ...
#
#                                         about_tokenised  cluster
# 2790  [foundations, faith_action, program, designed,...       33
# 2922  [foundations, program, faith_action®, designed...       33
# 3088  [foundations, faith_action, program, designed,...       33
# 3110  [foundations, faith_action, program, designed,...       33
# 3111  [foundations, faith_action, program, designed,...       33
#
#
#                         33  freq      norm
# closure                3.0    14  0.214286
# ii                     6.0    62  0.096774
# faith_action          32.0   752  0.042553
# oversee                4.0   119  0.033613
# phase_ii               4.0   119  0.033613
# institution            3.0   103  0.029126
# supplemental           4.0   145  0.027586
# expand_continued      11.0   500  0.022000
# volunteer_caregiving  11.0   508  0.021654
# office_npo             5.0   243  0.020576
#
#
# 34
# 10
#                                                   title  \
# 182   Technical assistance and direction for the Rob...
# 703   Technical assistance and direction for the Rob...
# 1598  Technical assistance and direction for the Rob...
# 2419  Technical assistance and direction for the Rob...
# 4984  Technical assistance and direction for the Rob...
#
#                                         about_tokenised  cluster
# 182   [robert_wood, johnson, foundation, community, ...       34
# 703   [robert_wood, johnson, foundation, community, ...       34
# 1598  [robert_wood, johnson, foundation, community, ...       34
# 2419  [robert_wood, johnson, foundation, community, ...       34
# 4984  [robert_wood, johnson, foundation, community, ...       34
#
#
#                              34  freq      norm
# nomination_selection        6.0     8  0.750000
# problemsthis                8.0    15  0.533333
# chl                         5.0    21  0.238095
# achieving_rwjfs            10.0    53  0.188679
# recognition_contributions  10.0    53  0.188679
# individuals_permanent      10.0    53  0.188679
# conducts                    5.0    38  0.131579
# widespread                 10.0   115  0.086957
# visibility                  4.0    81  0.049383
# leaders                    62.0  1903  0.032580
#
#
# 40
# 22
#                                          title  \
# 247  SmokeLess States Program - Implementation
# 614  SmokeLess States Program - Implementation
# 615  SmokeLess States Program - Implementation
# 618  SmokeLess States Program - Implementation
# 619  SmokeLess States Program - Implementation
#
#                                        about_tokenised  cluster
# 247  [foundations, smokeless_states, national, toba...       40
# 614  [foundations, smokeless_states, national, toba...       40
# 615  [foundations, smokeless_states, national, toba...       40
# 618  [foundations, smokeless_states, national, toba...       40
# 619  [foundations, smokeless_states, national, toba...       40
#
#
#                      40  freq      norm
# lobbying_kind      13.0    21  0.619048
# smokeless_states   27.0   116  0.232759
# statewide          51.0   632  0.080696
# tobacco           134.0  2092  0.064054
# comprehensive      37.0  1019  0.036310
# award              14.0   409  0.034230
# made               14.0   491  0.028513
# coalitions         16.0   598  0.026756
# control            28.0  1080  0.025926
# coalition          32.0  1269  0.025217
#
#
# 42
# 13
#                                                   title  \
# 236   Technical assistance and direction for the Rob...
# 1117  Technical assistance and direction for the Rob...
# 1946  Technical assistance and direction for the Rob...
# 2662  Technical assistance and direction for the Rob...
# 3425  Technical assistance and direction for the Rob...
#
#                                         about_tokenised  cluster
# 236   [robert_wood, johnson, clinical, scholars, pro...       42
# 1117  [robert_wood, johnson, clinical, scholars, pro...       42
# 1946  [robert_wood, johnson, clinical, scholars, pro...       42
# 2662  [robert_wood, johnson, clinical, scholars, pro...       42
# 3425  [robert_wood, johnson, clinical, scholars, pro...       42
#
#
#                           42  freq      norm
# csp                     15.0    19  0.789474
# appointment_monitoring   7.0     9  0.777778
# academia_st             12.0    58  0.206897
# augment_clinical        12.0    58  0.206897
# skills_perspectives     12.0    58  0.206897
# positions_within        12.0    58  0.206897
# necessary_achieving     12.0    58  0.206897
# outside_walls           12.0    59  0.203390
# selecting                7.0    65  0.107692
# visibility               8.0    81  0.098765
#
#
# 43
# 13
#                                                   title  \
# 7049  Consulting and technical assistance for RWJF's...
# 7050  Consulting and technical assistance for RWJF's...
# 7051  Consulting and technical assistance for RWJF's...
# 7299  Consulting and technical assistance for RWJF's...
# 7300  Consulting and technical assistance for RWJF's...
#
#                                         about_tokenised  cluster
# 7049  [foundations, initiative, tobacco, policy, cha...       43
# 7050  [foundations, initiative, tobacco, policy, cha...       43
# 7051  [foundations, initiative, tobacco, policy, cha...       43
# 7299  [foundations, initiative, tobacco, policy, cha...       43
# 7300  [foundations, initiative, tobacco, policy, cha...       43
#
#
#                            43  freq      norm
# webcast_trainings         8.0     8  1.000000
# tpc                      31.0    37  0.837838
# interested_advocating    13.0    98  0.132653
# collaborative_healthier  13.0    99  0.131313
# consultants              16.0   143  0.111888
# enhancing                 8.0   147  0.054422
# cessation                13.0   324  0.040123
# additionally              8.0   205  0.039024
# investment               13.0   351  0.037037
# tribal                   13.0   386  0.033679
#
#
# 45
# 14
#                                                   title  \
# 1197  Technical assistance and direction for RWJF's ...
# 2043  Technical assistance and direction for RWJF's ...
# 2871  Technical assistance and direction for RWJF's ...
# 3608  Technical assistance and direction for RWJF's ...
# 4098  Technical assistance and direction for RWJF's ...
#
#                                         about_tokenised  cluster
# 1197  [foundations, investigator_awards, health, pol...       45
# 2043  [foundations, investigator_awards, health, pol...       45
# 2871  [foundations, investigator_awards, health, pol...       45
# 3608  [foundations, investigator_awards, health, pol...       45
# 4098  [foundations, investigator_awards, health, pol...       45
#
#
#                        45  freq      norm
# highly_qualified     13.0    30  0.433333
# administering        13.0    36  0.361111
# basethis             11.0    35  0.314286
# investigator_awards  16.0   135  0.118519
# investigators_would  13.0   117  0.111111
# major_works          13.0   117  0.111111
# fields_knowledge     13.0   118  0.110169
# promise               8.0   103  0.077670
# investigators        24.0   342  0.070175
# applicants            9.0   149  0.060403
#
#
# 47
# 15
#                                                   title  \
# 9286  Caring Across Communities: Addressing Mental H...
# 9287  Caring Across Communities: Addressing Mental H...
# 9288  Caring Across Communities: Addressing Mental H...
# 9289  Caring Across Communities: Addressing Mental H...
# 9290  Caring Across Communities: Addressing Mental H...
#
#                                         about_tokenised  cluster
# 9286  [foundations, program, caring, across, communi...       47
# 9287  [foundations, program, caring, across, communi...       47
# 9288  [foundations, program, caring, across, communi...       47
# 9289  [foundations, program, caring, across, communi...       47
# 9290  [foundations, program, caring, across, communi...       47
#
#
#                        47  freq      norm
# refugee_familiesthe   8.0     8  1.000000
# residing_immigrant   15.0    16  0.937500
# overcoming_cultural  15.0    16  0.937500
# require_emphasis     15.0    16  0.937500
# refugee              13.0    50  0.260000
# connected            15.0    58  0.258621
# immigrant            17.0   147  0.115646
# caring               15.0   160  0.093750
# language             16.0   210  0.076190
# mental               72.0  1026  0.070175
#
#
# 57
# 13
#                                                   title  \
# 1982  Robert Wood Johnson Foundation Scholars in Hea...
# 5209  Robert Wood Johnson Foundation Scholars in Hea...
# 5635  Robert Wood Johnson Foundation Scholars in Hea...
# 8071  Robert Wood Johnson Foundation Scholars in Hea...
# 8846  Robert Wood Johnson Foundation Scholars in Hea...
#
#                                         about_tokenised  cluster
# 1982  [foundations, scholars, health, policy, resear...       57
# 5209  [foundations, scholars, health, policy, resear...       57
# 5635  [foundations, scholars, health, policy, resear...       57
# 8071  [foundations, scholars, health, policy, resear...       57
# 8846  [foundations, scholars, health, policy, resear...       57
#
#
#                           57  freq      norm
# interaction_professors   9.0     9  1.000000
# private_arenas           9.0     9  1.000000
# familiar_challenges      9.0     9  1.000000
# fostering_thirst         9.0    10  0.900000
# postdoctoral            23.0    49  0.469388
# researchthis            10.0    23  0.434783
# sociology_advance       13.0    30  0.433333
# promising_graduates     13.0    30  0.433333
# disciplines_economics   13.0    32  0.406250
# drawn                   10.0    40  0.250000

# %% [markdown]
# Ok - this seems to be picking up the 'duplicate' programmes. Maybe we can wrap them up together and redo the
# cluster analysis
